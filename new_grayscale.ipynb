# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("downloads/books.jpg")

# %%
print(image)
# Out:
# [[[160 157 153]
#   [158 155 150]
#   [153 151 143]
#   ...
#   [133 161 162]
#   [129 160 163]
#   [129 163 163]]
#
#  [[158 157 153]
#   [155 155 149]
#   [150 151 142]
#   ...
#   [131 159 160]
#   [130 161 162]
#   [130 164 163]]
#
#  [[158 159 155]
#   [155 157 151]
#   [154 157 148]
#   ...
#   [131 156 158]
#   [130 161 160]
#   [130 163 159]]
#
#  ...
#
#  [[  7  15  14]
#   [  5  12   9]
#   [ 25  32  25]
#   ...
#   [244 244 238]
#   [245 242 237]
#   [243 240 235]]
#
#  [[  0   0   4]
#   [  0   3   7]
#   [  0   2   3]
#   ...
#   [246 243 238]
#   [246 243 238]
#   [244 241 237]]
#
#  [[  0   1  11]
#   [ 12  11  20]
#   [  2   0   6]
#   ...
#   [246 243 238]
#   [246 243 238]
#   [244 241 237]]]

# %%
plt.imshow(image)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
print(image_gray)
# Out:
# [[156 154 149 ... 158 157 159]
#  [156 153 148 ... 156 158 160]
#  [158 155 154 ... 154 157 158]
#  ...
#  [ 14  10  29 ... 242 241 239]
#  [  1   4   2 ... 242 242 240]
#  [  4  14   2 ... 242 242 240]]

# %%
plt.imshow(image_gray)

# %%
image_gray = cv2.cvtColor(image_gray, cv2.COLOR_GRAY2RGB)

# %%
plt.imshow(image_gray)
