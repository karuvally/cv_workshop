# %%
# essential libraries
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the image
image = cv2.imread('downloads/coins.jpg')
plt.imshow(image)

# %%
# convert original image to gray
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)

# %%
# perform 5x5 gaussian blur
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
plt.imshow(blurred_image)

# %%
# convert image to binary
_, inverted_binary_image = cv2.threshold(blurred_image, 130, 255, cv2.THRESH_BINARY)
plt.imshow(inverted_binary_image)

# %%
# lets highlight the coins
binary_image = cv2.bitwise_not(inverted_binary_image)
plt.imshow(binary_image)

# %%
# find the contours
_, coin_contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
print(coin_contours)
# Out:
# [array([[[548, 559]],
#
#        [[547, 560]],
#
#        [[543, 560]],
#
#        [[542, 561]],
#
#        [[539, 561]],
#
#        [[538, 562]],
#
#        [[536, 562]],
#
#        [[535, 563]],
#
#        [[534, 563]],
#
#        [[533, 564]],
#
#        [[532, 564]],
#
#        [[531, 565]],
#
#        [[530, 565]],
#
#        [[529, 566]],
#
#        [[527, 566]],
#
#        [[526, 567]],
#
#        [[525, 567]],
#
#        [[524, 568]],
#
#        [[523, 568]],
#
#        [[519, 572]],
#
#        [[518, 572]],
#
#        [[510, 580]],
#
#        [[510, 581]],
#
#        [[507, 584]],
#
#        [[507, 585]],
#
#        [[505, 587]],
#
#        [[505, 588]],
#
#        [[504, 589]],
#
#        [[504, 590]],
#
#        [[502, 592]],
#
#        [[502, 594]],
#
#        [[501, 595]],
#
#        [[501, 596]],
#
#        [[500, 597]],
#
#        [[500, 598]],
#
#        [[499, 599]],
#
#        [[499, 601]],
#
#        [[498, 602]],
#
#        [[498, 604]],
#
#        [[497, 605]],
#
#        [[497, 608]],
#
#        [[496, 609]],
#
#        [[496, 615]],
#
#        [[495, 616]],
#
#        [[495, 627]],
#
#        [[496, 628]],
#
#        [[496, 634]],
#
#        [[497, 635]],
#
#        [[497, 638]],
#
#        [[498, 639]],
#
#        [[498, 641]],
#
#        [[499, 642]],
#
#        [[499, 644]],
#
#        [[500, 645]],
#
#        [[500, 646]],
#
#        [[501, 647]],
#
#        [[501, 649]],
#
#        [[503, 651]],
#
#        [[503, 653]],
#
#        [[504, 654]],
#
#        [[504, 655]],
#
#        [[506, 657]],
#
#        [[506, 658]],
#
#        [[508, 660]],
#
#        [[509, 660]],
#
#        [[510, 661]],
#
#        [[511, 661]],
#
#        [[512, 662]],
#
#        [[512, 664]],
#
#        [[520, 672]],
#
#        [[521, 672]],
#
#        [[525, 676]],
#
#        [[526, 676]],
#
#        [[528, 678]],
#
#        [[530, 678]],
#
#        [[532, 680]],
#
#        [[533, 680]],
#
#        [[534, 681]],
#
#        [[536, 681]],
#
#        [[537, 682]],
#
#        [[539, 682]],
#
#        [[540, 683]],
#
#        [[543, 683]],
#
#        [[544, 684]],
#
#        [[548, 684]],
#
#        [[549, 685]],
#
#        [[565, 685]],
#
#        [[566, 684]],
#
#        [[570, 684]],
#
#        [[571, 683]],
#
#        [[574, 683]],
#
#        [[575, 682]],
#
#        [[576, 682]],
#
#        [[577, 681]],
#
#        [[579, 681]],
#
#        [[580, 680]],
#
#        [[582, 680]],
#
#        [[583, 679]],
#
#        [[584, 679]],
#
#        [[585, 678]],
#
#        [[586, 678]],
#
#        [[587, 677]],
#
#        [[588, 677]],
#
#        [[590, 675]],
#
#        [[591, 675]],
#
#        [[593, 673]],
#
#        [[594, 673]],
#
#        [[600, 667]],
#
#        [[601, 667]],
#
#        [[602, 666]],
#
#        [[602, 665]],
#
#        [[607, 660]],
#
#        [[607, 659]],
#
#        [[609, 657]],
#
#        [[609, 656]],
#
#        [[611, 654]],
#
#        [[611, 652]],
#
#        [[613, 650]],
#
#        [[613, 649]],
#
#        [[614, 648]],
#
#        [[614, 646]],
#
#        [[615, 645]],
#
#        [[615, 644]],
#
#        [[616, 643]],
#
#        [[616, 642]],
#
#        [[617, 641]],
#
#        [[617, 638]],
#
#        [[618, 637]],
#
#        [[618, 634]],
#
#        [[619, 633]],
#
#        [[619, 628]],
#
#        [[620, 627]],
#
#        [[620, 617]],
#
#        [[619, 616]],
#
#        [[619, 610]],
#
#        [[618, 609]],
#
#        [[618, 606]],
#
#        [[617, 605]],
#
#        [[617, 603]],
#
#        [[616, 602]],
#
#        [[616, 600]],
#
#        [[615, 599]],
#
#        [[615, 598]],
#
#        [[614, 597]],
#
#        [[614, 596]],
#
#        [[613, 595]],
#
#        [[613, 594]],
#
#        [[612, 593]],
#
#        [[612, 592]],
#
#        [[611, 591]],
#
#        [[611, 590]],
#
#        [[610, 589]],
#
#        [[609, 589]],
#
#        [[608, 588]],
#
#        [[608, 586]],
#
#        [[605, 583]],
#
#        [[605, 582]],
#
#        [[604, 581]],
#
#        [[604, 580]],
#
#        [[598, 574]],
#
#        [[597, 574]],
#
#        [[596, 573]],
#
#        [[596, 572]],
#
#        [[595, 572]],
#
#        [[593, 570]],
#
#        [[592, 570]],
#
#        [[590, 568]],
#
#        [[589, 568]],
#
#        [[587, 566]],
#
#        [[586, 566]],
#
#        [[585, 565]],
#
#        [[584, 565]],
#
#        [[583, 564]],
#
#        [[582, 564]],
#
#        [[581, 563]],
#
#        [[579, 563]],
#
#        [[578, 562]],
#
#        [[576, 562]],
#
#        [[575, 561]],
#
#        [[573, 561]],
#
#        [[572, 560]],
#
#        [[568, 560]],
#
#        [[567, 559]]], dtype=int32), array([[[334, 497]],
#
#        [[333, 498]],
#
#        [[323, 498]],
#
#        [[322, 499]],
#
#        [[317, 499]],
#
#        [[316, 500]],
#
#        [[315, 500]],
#
#        [[315, 501]],
#
#        [[313, 503]],
#
#        [[311, 503]],
#
#        [[310, 502]],
#
#        [[309, 502]],
#
#        [[308, 503]],
#
#        [[306, 503]],
#
#        [[305, 504]],
#
#        [[304, 504]],
#
#        [[303, 505]],
#
#        [[302, 505]],
#
#        [[301, 506]],
#
#        [[300, 506]],
#
#        [[298, 508]],
#
#        [[297, 508]],
#
#        [[296, 509]],
#
#        [[295, 509]],
#
#        [[292, 512]],
#
#        [[291, 512]],
#
#        [[283, 520]],
#
#        [[283, 521]],
#
#        [[279, 525]],
#
#        [[279, 526]],
#
#        [[277, 528]],
#
#        [[277, 529]],
#
#        [[275, 531]],
#
#        [[275, 532]],
#
#        [[274, 533]],
#
#        [[274, 534]],
#
#        [[273, 535]],
#
#        [[273, 536]],
#
#        [[272, 537]],
#
#        [[272, 538]],
#
#        [[271, 539]],
#
#        [[271, 540]],
#
#        [[270, 541]],
#
#        [[270, 544]],
#
#        [[269, 545]],
#
#        [[269, 547]],
#
#        [[268, 548]],
#
#        [[268, 551]],
#
#        [[267, 552]],
#
#        [[267, 558]],
#
#        [[266, 559]],
#
#        [[266, 567]],
#
#        [[267, 568]],
#
#        [[267, 576]],
#
#        [[268, 577]],
#
#        [[268, 580]],
#
#        [[269, 581]],
#
#        [[269, 583]],
#
#        [[270, 584]],
#
#        [[270, 586]],
#
#        [[271, 587]],
#
#        [[271, 589]],
#
#        [[272, 590]],
#
#        [[272, 591]],
#
#        [[273, 592]],
#
#        [[273, 593]],
#
#        [[275, 595]],
#
#        [[275, 596]],
#
#        [[276, 597]],
#
#        [[276, 598]],
#
#        [[278, 600]],
#
#        [[278, 601]],
#
#        [[281, 604]],
#
#        [[281, 605]],
#
#        [[287, 611]],
#
#        [[288, 611]],
#
#        [[292, 615]],
#
#        [[293, 615]],
#
#        [[295, 617]],
#
#        [[296, 617]],
#
#        [[298, 619]],
#
#        [[299, 619]],
#
#        [[300, 620]],
#
#        [[301, 620]],
#
#        [[302, 621]],
#
#        [[304, 621]],
#
#        [[305, 622]],
#
#        [[306, 622]],
#
#        [[307, 623]],
#
#        [[309, 623]],
#
#        [[310, 624]],
#
#        [[312, 624]],
#
#        [[313, 625]],
#
#        [[314, 625]],
#
#        [[315, 626]],
#
#        [[320, 626]],
#
#        [[321, 627]],
#
#        [[328, 627]],
#
#        [[329, 628]],
#
#        [[333, 628]],
#
#        [[334, 627]],
#
#        [[342, 627]],
#
#        [[343, 626]],
#
#        [[347, 626]],
#
#        [[348, 625]],
#
#        [[350, 625]],
#
#        [[351, 624]],
#
#        [[353, 624]],
#
#        [[354, 623]],
#
#        [[356, 623]],
#
#        [[357, 622]],
#
#        [[358, 622]],
#
#        [[359, 621]],
#
#        [[361, 621]],
#
#        [[362, 620]],
#
#        [[363, 620]],
#
#        [[365, 618]],
#
#        [[366, 618]],
#
#        [[368, 616]],
#
#        [[369, 616]],
#
#        [[372, 613]],
#
#        [[373, 613]],
#
#        [[384, 602]],
#
#        [[384, 601]],
#
#        [[386, 599]],
#
#        [[386, 598]],
#
#        [[388, 596]],
#
#        [[388, 595]],
#
#        [[389, 594]],
#
#        [[389, 593]],
#
#        [[390, 592]],
#
#        [[390, 591]],
#
#        [[392, 589]],
#
#        [[392, 588]],
#
#        [[393, 587]],
#
#        [[393, 585]],
#
#        [[394, 584]],
#
#        [[394, 582]],
#
#        [[395, 581]],
#
#        [[395, 579]],
#
#        [[396, 578]],
#
#        [[396, 576]],
#
#        [[397, 575]],
#
#        [[397, 572]],
#
#        [[398, 571]],
#
#        [[398, 553]],
#
#        [[397, 552]],
#
#        [[397, 547]],
#
#        [[396, 546]],
#
#        [[396, 544]],
#
#        [[395, 543]],
#
#        [[395, 541]],
#
#        [[394, 540]],
#
#        [[394, 538]],
#
#        [[393, 537]],
#
#        [[393, 536]],
#
#        [[392, 535]],
#
#        [[392, 534]],
#
#        [[391, 533]],
#
#        [[391, 532]],
#
#        [[390, 531]],
#
#        [[390, 530]],
#
#        [[388, 528]],
#
#        [[388, 527]],
#
#        [[387, 526]],
#
#        [[387, 525]],
#
#        [[382, 520]],
#
#        [[382, 519]],
#
#        [[378, 515]],
#
#        [[377, 515]],
#
#        [[372, 510]],
#
#        [[371, 510]],
#
#        [[369, 508]],
#
#        [[368, 508]],
#
#        [[366, 506]],
#
#        [[365, 506]],
#
#        [[364, 505]],
#
#        [[363, 505]],
#
#        [[362, 504]],
#
#        [[361, 504]],
#
#        [[360, 503]],
#
#        [[358, 503]],
#
#        [[357, 502]],
#
#        [[356, 502]],
#
#        [[355, 501]],
#
#        [[353, 501]],
#
#        [[352, 500]],
#
#        [[350, 500]],
#
#        [[349, 499]],
#
#        [[344, 499]],
#
#        [[343, 498]],
#
#        [[342, 498]],
#
#        [[341, 497]]], dtype=int32), array([[[247, 472]]], dtype=int32), array([[[290, 471]]], dtype=int32), array([[[295, 469]],
#
#        [[294, 470]],
#
#        [[293, 470]],
#
#        [[295, 470]],
#
#        [[296, 469]]], dtype=int32), array([[[631, 370]],
#
#        [[630, 371]],
#
#        [[625, 371]],
#
#        [[624, 372]],
#
#        [[622, 372]],
#
#        [[621, 373]],
#
#        [[618, 373]],
#
#        [[617, 374]],
#
#        [[615, 374]],
#
#        [[614, 375]],
#
#        [[612, 375]],
#
#        [[611, 376]],
#
#        [[610, 376]],
#
#        [[609, 377]],
#
#        [[608, 377]],
#
#        [[607, 378]],
#
#        [[606, 378]],
#
#        [[606, 379]],
#
#        [[605, 380]],
#
#        [[604, 380]],
#
#        [[603, 379]],
#
#        [[602, 380]],
#
#        [[601, 380]],
#
#        [[600, 381]],
#
#        [[599, 381]],
#
#        [[597, 383]],
#
#        [[595, 383]],
#
#        [[591, 387]],
#
#        [[590, 387]],
#
#        [[588, 389]],
#
#        [[588, 393]],
#
#        [[587, 394]],
#
#        [[586, 394]],
#
#        [[585, 395]],
#
#        [[584, 394]],
#
#        [[583, 394]],
#
#        [[577, 400]],
#
#        [[577, 401]],
#
#        [[575, 403]],
#
#        [[575, 404]],
#
#        [[572, 407]],
#
#        [[572, 408]],
#
#        [[571, 409]],
#
#        [[571, 410]],
#
#        [[570, 411]],
#
#        [[570, 412]],
#
#        [[569, 413]],
#
#        [[569, 414]],
#
#        [[568, 415]],
#
#        [[568, 416]],
#
#        [[567, 417]],
#
#        [[567, 418]],
#
#        [[566, 419]],
#
#        [[566, 421]],
#
#        [[565, 422]],
#
#        [[565, 424]],
#
#        [[564, 425]],
#
#        [[564, 427]],
#
#        [[563, 428]],
#
#        [[563, 431]],
#
#        [[562, 432]],
#
#        [[562, 435]],
#
#        [[561, 436]],
#
#        [[561, 446]],
#
#        [[560, 447]],
#
#        [[560, 454]],
#
#        [[561, 455]],
#
#        [[561, 461]],
#
#        [[562, 462]],
#
#        [[562, 466]],
#
#        [[563, 467]],
#
#        [[563, 470]],
#
#        [[564, 471]],
#
#        [[564, 473]],
#
#        [[565, 474]],
#
#        [[565, 476]],
#
#        [[566, 477]],
#
#        [[566, 479]],
#
#        [[567, 480]],
#
#        [[567, 481]],
#
#        [[568, 482]],
#
#        [[568, 484]],
#
#        [[569, 485]],
#
#        [[569, 486]],
#
#        [[571, 488]],
#
#        [[571, 489]],
#
#        [[572, 490]],
#
#        [[572, 491]],
#
#        [[574, 493]],
#
#        [[574, 494]],
#
#        [[576, 496]],
#
#        [[576, 497]],
#
#        [[577, 498]],
#
#        [[578, 498]],
#
#        [[579, 499]],
#
#        [[579, 500]],
#
#        [[583, 504]],
#
#        [[584, 504]],
#
#        [[593, 513]],
#
#        [[594, 513]],
#
#        [[598, 517]],
#
#        [[599, 517]],
#
#        [[602, 520]],
#
#        [[603, 520]],
#
#        [[604, 521]],
#
#        [[605, 521]],
#
#        [[606, 522]],
#
#        [[608, 522]],
#
#        [[609, 523]],
#
#        [[610, 523]],
#
#        [[611, 524]],
#
#        [[612, 524]],
#
#        [[613, 525]],
#
#        [[615, 525]],
#
#        [[616, 526]],
#
#        [[619, 526]],
#
#        [[620, 527]],
#
#        [[622, 527]],
#
#        [[623, 528]],
#
#        [[627, 528]],
#
#        [[628, 529]],
#
#        [[646, 529]],
#
#        [[647, 528]],
#
#        [[652, 528]],
#
#        [[653, 527]],
#
#        [[659, 527]],
#
#        [[660, 526]],
#
#        [[662, 526]],
#
#        [[663, 525]],
#
#        [[664, 525]],
#
#        [[665, 524]],
#
#        [[668, 524]],
#
#        [[669, 523]],
#
#        [[671, 523]],
#
#        [[672, 522]],
#
#        [[673, 522]],
#
#        [[674, 521]],
#
#        [[675, 521]],
#
#        [[676, 520]],
#
#        [[677, 520]],
#
#        [[678, 519]],
#
#        [[679, 519]],
#
#        [[681, 517]],
#
#        [[682, 517]],
#
#        [[683, 516]],
#
#        [[684, 516]],
#
#        [[686, 514]],
#
#        [[687, 514]],
#
#        [[691, 510]],
#
#        [[692, 510]],
#
#        [[696, 506]],
#
#        [[696, 505]],
#
#        [[697, 504]],
#
#        [[698, 504]],
#
#        [[700, 502]],
#
#        [[700, 501]],
#
#        [[704, 497]],
#
#        [[704, 496]],
#
#        [[708, 492]],
#
#        [[708, 491]],
#
#        [[709, 490]],
#
#        [[709, 489]],
#
#        [[710, 488]],
#
#        [[710, 487]],
#
#        [[711, 486]],
#
#        [[711, 485]],
#
#        [[712, 484]],
#
#        [[712, 483]],
#
#        [[713, 482]],
#
#        [[713, 481]],
#
#        [[714, 480]],
#
#        [[714, 479]],
#
#        [[715, 478]],
#
#        [[715, 476]],
#
#        [[716, 475]],
#
#        [[716, 473]],
#
#        [[717, 472]],
#
#        [[717, 469]],
#
#        [[718, 468]],
#
#        [[718, 464]],
#
#        [[719, 463]],
#
#        [[719, 456]],
#
#        [[720, 455]],
#
#        [[720, 448]],
#
#        [[719, 447]],
#
#        [[719, 436]],
#
#        [[718, 435]],
#
#        [[718, 432]],
#
#        [[717, 431]],
#
#        [[717, 428]],
#
#        [[716, 427]],
#
#        [[716, 425]],
#
#        [[715, 424]],
#
#        [[715, 422]],
#
#        [[714, 421]],
#
#        [[714, 419]],
#
#        [[713, 418]],
#
#        [[713, 417]],
#
#        [[712, 416]],
#
#        [[712, 415]],
#
#        [[709, 412]],
#
#        [[709, 411]],
#
#        [[708, 410]],
#
#        [[708, 408]],
#
#        [[706, 406]],
#
#        [[706, 405]],
#
#        [[705, 404]],
#
#        [[705, 403]],
#
#        [[700, 398]],
#
#        [[700, 397]],
#
#        [[691, 388]],
#
#        [[690, 388]],
#
#        [[687, 385]],
#
#        [[686, 385]],
#
#        [[684, 383]],
#
#        [[683, 383]],
#
#        [[681, 381]],
#
#        [[680, 381]],
#
#        [[679, 380]],
#
#        [[678, 380]],
#
#        [[676, 378]],
#
#        [[675, 378]],
#
#        [[674, 377]],
#
#        [[672, 377]],
#
#        [[671, 376]],
#
#        [[670, 376]],
#
#        [[669, 375]],
#
#        [[667, 375]],
#
#        [[666, 374]],
#
#        [[665, 374]],
#
#        [[664, 373]],
#
#        [[661, 373]],
#
#        [[660, 372]],
#
#        [[657, 372]],
#
#        [[656, 371]],
#
#        [[649, 371]],
#
#        [[648, 370]]], dtype=int32), array([[[449, 365]],
#
#        [[448, 366]],
#
#        [[444, 366]],
#
#        [[443, 367]],
#
#        [[442, 367]],
#
#        [[441, 368]],
#
#        [[440, 368]],
#
#        [[439, 369]],
#
#        [[435, 369]],
#
#        [[434, 370]],
#
#        [[432, 370]],
#
#        [[431, 371]],
#
#        [[430, 371]],
#
#        [[428, 373]],
#
#        [[426, 373]],
#
#        [[425, 374]],
#
#        [[424, 374]],
#
#        [[423, 375]],
#
#        [[422, 375]],
#
#        [[421, 376]],
#
#        [[420, 376]],
#
#        [[416, 380]],
#
#        [[415, 380]],
#
#        [[410, 385]],
#
#        [[409, 385]],
#
#        [[407, 387]],
#
#        [[407, 388]],
#
#        [[404, 391]],
#
#        [[404, 392]],
#
#        [[402, 394]],
#
#        [[402, 395]],
#
#        [[401, 396]],
#
#        [[401, 397]],
#
#        [[399, 399]],
#
#        [[399, 400]],
#
#        [[398, 401]],
#
#        [[398, 402]],
#
#        [[397, 403]],
#
#        [[397, 405]],
#
#        [[396, 406]],
#
#        [[396, 407]],
#
#        [[395, 408]],
#
#        [[395, 410]],
#
#        [[394, 411]],
#
#        [[394, 414]],
#
#        [[393, 415]],
#
#        [[393, 419]],
#
#        [[392, 420]],
#
#        [[392, 437]],
#
#        [[393, 438]],
#
#        [[393, 443]],
#
#        [[394, 444]],
#
#        [[394, 447]],
#
#        [[395, 448]],
#
#        [[395, 449]],
#
#        [[396, 450]],
#
#        [[396, 452]],
#
#        [[397, 453]],
#
#        [[397, 455]],
#
#        [[398, 456]],
#
#        [[398, 457]],
#
#        [[399, 458]],
#
#        [[399, 459]],
#
#        [[400, 460]],
#
#        [[400, 461]],
#
#        [[402, 463]],
#
#        [[402, 464]],
#
#        [[404, 466]],
#
#        [[404, 467]],
#
#        [[408, 471]],
#
#        [[408, 472]],
#
#        [[413, 477]],
#
#        [[414, 477]],
#
#        [[418, 481]],
#
#        [[419, 481]],
#
#        [[421, 483]],
#
#        [[422, 483]],
#
#        [[423, 484]],
#
#        [[424, 484]],
#
#        [[425, 485]],
#
#        [[426, 485]],
#
#        [[427, 486]],
#
#        [[428, 486]],
#
#        [[429, 487]],
#
#        [[430, 487]],
#
#        [[431, 488]],
#
#        [[433, 488]],
#
#        [[434, 489]],
#
#        [[435, 489]],
#
#        [[436, 490]],
#
#        [[438, 490]],
#
#        [[439, 491]],
#
#        [[442, 491]],
#
#        [[443, 492]],
#
#        [[447, 492]],
#
#        [[448, 493]],
#
#        [[464, 493]],
#
#        [[465, 492]],
#
#        [[468, 492]],
#
#        [[468, 490]],
#
#        [[465, 490]],
#
#        [[464, 489]],
#
#        [[465, 488]],
#
#        [[468, 488]],
#
#        [[469, 487]],
#
#        [[470, 487]],
#
#        [[471, 486]],
#
#        [[475, 486]],
#
#        [[476, 485]],
#
#        [[477, 485]],
#
#        [[478, 484]],
#
#        [[479, 484]],
#
#        [[480, 483]],
#
#        [[482, 483]],
#
#        [[483, 484]],
#
#        [[481, 486]],
#
#        [[480, 486]],
#
#        [[479, 487]],
#
#        [[477, 487]],
#
#        [[477, 488]],
#
#        [[476, 489]],
#
#        [[479, 489]],
#
#        [[480, 488]],
#
#        [[481, 488]],
#
#        [[482, 487]],
#
#        [[484, 487]],
#
#        [[485, 486]],
#
#        [[486, 486]],
#
#        [[488, 484]],
#
#        [[489, 484]],
#
#        [[490, 483]],
#
#        [[491, 483]],
#
#        [[493, 481]],
#
#        [[494, 481]],
#
#        [[498, 477]],
#
#        [[499, 477]],
#
#        [[507, 469]],
#
#        [[507, 468]],
#
#        [[509, 466]],
#
#        [[509, 465]],
#
#        [[510, 464]],
#
#        [[510, 463]],
#
#        [[513, 460]],
#
#        [[513, 458]],
#
#        [[515, 456]],
#
#        [[515, 455]],
#
#        [[516, 454]],
#
#        [[516, 452]],
#
#        [[517, 451]],
#
#        [[517, 450]],
#
#        [[518, 449]],
#
#        [[518, 447]],
#
#        [[519, 446]],
#
#        [[519, 444]],
#
#        [[520, 443]],
#
#        [[520, 439]],
#
#        [[521, 438]],
#
#        [[521, 420]],
#
#        [[520, 419]],
#
#        [[520, 415]],
#
#        [[519, 414]],
#
#        [[519, 412]],
#
#        [[518, 411]],
#
#        [[518, 410]],
#
#        [[517, 409]],
#
#        [[517, 407]],
#
#        [[516, 406]],
#
#        [[516, 404]],
#
#        [[514, 402]],
#
#        [[514, 400]],
#
#        [[513, 399]],
#
#        [[513, 398]],
#
#        [[512, 397]],
#
#        [[512, 396]],
#
#        [[510, 394]],
#
#        [[510, 393]],
#
#        [[509, 392]],
#
#        [[509, 391]],
#
#        [[504, 386]],
#
#        [[504, 385]],
#
#        [[499, 380]],
#
#        [[498, 380]],
#
#        [[495, 377]],
#
#        [[494, 377]],
#
#        [[492, 375]],
#
#        [[491, 375]],
#
#        [[489, 373]],
#
#        [[488, 373]],
#
#        [[487, 372]],
#
#        [[486, 372]],
#
#        [[485, 371]],
#
#        [[484, 371]],
#
#        [[483, 370]],
#
#        [[482, 370]],
#
#        [[481, 369]],
#
#        [[479, 369]],
#
#        [[478, 368]],
#
#        [[476, 368]],
#
#        [[475, 367]],
#
#        [[472, 367]],
#
#        [[471, 366]],
#
#        [[467, 366]],
#
#        [[466, 365]]], dtype=int32), array([[[380, 322]],
#
#        [[382, 322]]], dtype=int32), array([[[375, 322]],
#
#        [[376, 322]]], dtype=int32), array([[[367, 321]]], dtype=int32), array([[[391, 319]],
#
#        [[390, 320]],
#
#        [[389, 320]],
#
#        [[392, 320]],
#
#        [[393, 319]]], dtype=int32), array([[[284, 319]],
#
#        [[284, 320]],
#
#        [[285, 321]],
#
#        [[288, 321]],
#
#        [[289, 322]],
#
#        [[290, 322]],
#
#        [[291, 323]],
#
#        [[294, 323]],
#
#        [[296, 325]],
#
#        [[295, 326]],
#
#        [[290, 326]],
#
#        [[289, 325]],
#
#        [[286, 325]],
#
#        [[285, 324]],
#
#        [[278, 324]],
#
#        [[277, 323]],
#
#        [[264, 323]],
#
#        [[263, 322]],
#
#        [[256, 322]],
#
#        [[255, 323]],
#
#        [[249, 323]],
#
#        [[248, 324]],
#
#        [[246, 324]],
#
#        [[245, 325]],
#
#        [[242, 325]],
#
#        [[240, 323]],
#
#        [[240, 322]],
#
#        [[239, 322]],
#
#        [[238, 323]],
#
#        [[236, 323]],
#
#        [[235, 324]],
#
#        [[232, 324]],
#
#        [[231, 325]],
#
#        [[230, 325]],
#
#        [[229, 326]],
#
#        [[228, 326]],
#
#        [[227, 327]],
#
#        [[226, 327]],
#
#        [[225, 328]],
#
#        [[224, 328]],
#
#        [[222, 330]],
#
#        [[221, 330]],
#
#        [[219, 332]],
#
#        [[218, 332]],
#
#        [[213, 337]],
#
#        [[212, 337]],
#
#        [[205, 344]],
#
#        [[205, 345]],
#
#        [[201, 349]],
#
#        [[201, 350]],
#
#        [[199, 352]],
#
#        [[199, 353]],
#
#        [[197, 355]],
#
#        [[197, 356]],
#
#        [[196, 357]],
#
#        [[196, 358]],
#
#        [[194, 360]],
#
#        [[194, 361]],
#
#        [[193, 362]],
#
#        [[193, 364]],
#
#        [[192, 365]],
#
#        [[192, 366]],
#
#        [[191, 367]],
#
#        [[191, 368]],
#
#        [[190, 369]],
#
#        [[190, 372]],
#
#        [[189, 373]],
#
#        [[189, 375]],
#
#        [[188, 376]],
#
#        [[188, 380]],
#
#        [[187, 381]],
#
#        [[187, 388]],
#
#        [[186, 389]],
#
#        [[186, 402]],
#
#        [[187, 403]],
#
#        [[187, 409]],
#
#        [[188, 410]],
#
#        [[188, 414]],
#
#        [[189, 415]],
#
#        [[189, 417]],
#
#        [[190, 418]],
#
#        [[190, 420]],
#
#        [[191, 421]],
#
#        [[191, 423]],
#
#        [[192, 424]],
#
#        [[192, 426]],
#
#        [[193, 427]],
#
#        [[193, 428]],
#
#        [[194, 429]],
#
#        [[194, 430]],
#
#        [[196, 432]],
#
#        [[196, 433]],
#
#        [[197, 434]],
#
#        [[197, 435]],
#
#        [[198, 436]],
#
#        [[198, 437]],
#
#        [[200, 439]],
#
#        [[200, 440]],
#
#        [[203, 443]],
#
#        [[203, 444]],
#
#        [[214, 455]],
#
#        [[215, 455]],
#
#        [[216, 456]],
#
#        [[217, 455]],
#
#        [[218, 455]],
#
#        [[219, 456]],
#
#        [[219, 457]],
#
#        [[218, 458]],
#
#        [[219, 459]],
#
#        [[222, 459]],
#
#        [[223, 460]],
#
#        [[223, 461]],
#
#        [[226, 464]],
#
#        [[227, 464]],
#
#        [[228, 465]],
#
#        [[229, 465]],
#
#        [[230, 466]],
#
#        [[231, 466]],
#
#        [[232, 467]],
#
#        [[234, 467]],
#
#        [[235, 468]],
#
#        [[236, 468]],
#
#        [[237, 469]],
#
#        [[239, 469]],
#
#        [[240, 470]],
#
#        [[241, 470]],
#
#        [[240, 470]],
#
#        [[238, 468]],
#
#        [[237, 468]],
#
#        [[236, 467]],
#
#        [[234, 467]],
#
#        [[233, 466]],
#
#        [[233, 465]],
#
#        [[234, 464]],
#
#        [[236, 464]],
#
#        [[237, 465]],
#
#        [[238, 465]],
#
#        [[239, 466]],
#
#        [[245, 466]],
#
#        [[246, 467]],
#
#        [[248, 467]],
#
#        [[249, 468]],
#
#        [[257, 468]],
#
#        [[258, 469]],
#
#        [[260, 469]],
#
#        [[261, 468]],
#
#        [[263, 468]],
#
#        [[264, 469]],
#
#        [[272, 469]],
#
#        [[273, 468]],
#
#        [[282, 468]],
#
#        [[283, 467]],
#
#        [[285, 467]],
#
#        [[286, 466]],
#
#        [[289, 466]],
#
#        [[290, 465]],
#
#        [[293, 465]],
#
#        [[294, 464]],
#
#        [[295, 464]],
#
#        [[296, 463]],
#
#        [[298, 463]],
#
#        [[299, 462]],
#
#        [[300, 462]],
#
#        [[302, 460]],
#
#        [[304, 460]],
#
#        [[305, 459]],
#
#        [[306, 459]],
#
#        [[307, 458]],
#
#        [[308, 458]],
#
#        [[311, 455]],
#
#        [[312, 455]],
#
#        [[314, 453]],
#
#        [[315, 453]],
#
#        [[321, 447]],
#
#        [[322, 447]],
#
#        [[325, 444]],
#
#        [[326, 445]],
#
#        [[326, 446]],
#
#        [[321, 451]],
#
#        [[321, 452]],
#
#        [[317, 456]],
#
#        [[316, 456]],
#
#        [[311, 461]],
#
#        [[310, 461]],
#
#        [[309, 462]],
#
#        [[307, 462]],
#
#        [[306, 463]],
#
#        [[306, 464]],
#
#        [[307, 464]],
#
#        [[308, 463]],
#
#        [[309, 463]],
#
#        [[311, 461]],
#
#        [[312, 461]],
#
#        [[314, 459]],
#
#        [[315, 459]],
#
#        [[317, 457]],
#
#        [[318, 457]],
#
#        [[327, 448]],
#
#        [[327, 447]],
#
#        [[328, 446]],
#
#        [[326, 444]],
#
#        [[326, 443]],
#
#        [[327, 442]],
#
#        [[331, 442]],
#
#        [[336, 437]],
#
#        [[336, 436]],
#
#        [[337, 435]],
#
#        [[337, 434]],
#
#        [[339, 432]],
#
#        [[339, 431]],
#
#        [[340, 430]],
#
#        [[340, 429]],
#
#        [[341, 428]],
#
#        [[341, 427]],
#
#        [[342, 426]],
#
#        [[342, 425]],
#
#        [[343, 424]],
#
#        [[343, 423]],
#
#        [[344, 422]],
#
#        [[344, 420]],
#
#        [[345, 419]],
#
#        [[345, 418]],
#
#        [[346, 417]],
#
#        [[346, 415]],
#
#        [[347, 414]],
#
#        [[347, 411]],
#
#        [[348, 410]],
#
#        [[348, 407]],
#
#        [[349, 406]],
#
#        [[349, 385]],
#
#        [[348, 384]],
#
#        [[348, 380]],
#
#        [[347, 379]],
#
#        [[347, 377]],
#
#        [[346, 376]],
#
#        [[346, 373]],
#
#        [[345, 372]],
#
#        [[345, 371]],
#
#        [[344, 370]],
#
#        [[344, 368]],
#
#        [[343, 367]],
#
#        [[343, 366]],
#
#        [[342, 365]],
#
#        [[342, 364]],
#
#        [[340, 362]],
#
#        [[340, 361]],
#
#        [[339, 360]],
#
#        [[339, 359]],
#
#        [[338, 358]],
#
#        [[338, 357]],
#
#        [[337, 356]],
#
#        [[337, 355]],
#
#        [[335, 353]],
#
#        [[335, 352]],
#
#        [[333, 350]],
#
#        [[333, 349]],
#
#        [[329, 345]],
#
#        [[329, 344]],
#
#        [[328, 343]],
#
#        [[327, 343]],
#
#        [[326, 342]],
#
#        [[326, 341]],
#
#        [[324, 339]],
#
#        [[323, 339]],
#
#        [[317, 333]],
#
#        [[316, 333]],
#
#        [[314, 331]],
#
#        [[313, 331]],
#
#        [[311, 329]],
#
#        [[310, 329]],
#
#        [[309, 328]],
#
#        [[308, 328]],
#
#        [[307, 327]],
#
#        [[306, 327]],
#
#        [[305, 326]],
#
#        [[304, 326]],
#
#        [[303, 325]],
#
#        [[302, 325]],
#
#        [[301, 324]],
#
#        [[300, 324]],
#
#        [[299, 323]],
#
#        [[297, 323]],
#
#        [[296, 322]],
#
#        [[294, 322]],
#
#        [[293, 321]],
#
#        [[287, 321]],
#
#        [[286, 320]],
#
#        [[285, 320]]], dtype=int32), array([[[248, 319]],
#
#        [[247, 320]],
#
#        [[250, 320]],
#
#        [[251, 319]]], dtype=int32), array([[[274, 318]],
#
#        [[276, 318]]], dtype=int32), array([[[263, 317]],
#
#        [[264, 318]],
#
#        [[265, 317]],
#
#        [[266, 317]]], dtype=int32), array([[[760, 245]],
#
#        [[759, 246]],
#
#        [[754, 246]],
#
#        [[753, 247]],
#
#        [[748, 247]],
#
#        [[747, 248]],
#
#        [[744, 248]],
#
#        [[743, 249]],
#
#        [[742, 249]],
#
#        [[741, 250]],
#
#        [[739, 250]],
#
#        [[738, 251]],
#
#        [[736, 251]],
#
#        [[735, 252]],
#
#        [[734, 252]],
#
#        [[733, 253]],
#
#        [[732, 253]],
#
#        [[731, 254]],
#
#        [[730, 254]],
#
#        [[729, 255]],
#
#        [[728, 255]],
#
#        [[727, 256]],
#
#        [[726, 256]],
#
#        [[725, 257]],
#
#        [[724, 257]],
#
#        [[720, 261]],
#
#        [[719, 261]],
#
#        [[712, 268]],
#
#        [[712, 269]],
#
#        [[709, 272]],
#
#        [[709, 273]],
#
#        [[705, 277]],
#
#        [[705, 278]],
#
#        [[704, 279]],
#
#        [[704, 281]],
#
#        [[702, 283]],
#
#        [[701, 283]],
#
#        [[700, 284]],
#
#        [[700, 285]],
#
#        [[699, 286]],
#
#        [[699, 288]],
#
#        [[698, 289]],
#
#        [[698, 291]],
#
#        [[697, 292]],
#
#        [[697, 293]],
#
#        [[696, 294]],
#
#        [[696, 296]],
#
#        [[695, 297]],
#
#        [[695, 301]],
#
#        [[694, 302]],
#
#        [[694, 307]],
#
#        [[693, 308]],
#
#        [[693, 319]],
#
#        [[694, 320]],
#
#        [[694, 326]],
#
#        [[695, 327]],
#
#        [[695, 329]],
#
#        [[697, 329]],
#
#        [[698, 330]],
#
#        [[698, 331]],
#
#        [[697, 332]],
#
#        [[696, 332]],
#
#        [[696, 334]],
#
#        [[697, 335]],
#
#        [[698, 335]],
#
#        [[699, 336]],
#
#        [[701, 336]],
#
#        [[705, 340]],
#
#        [[705, 343]],
#
#        [[704, 344]],
#
#        [[703, 344]],
#
#        [[704, 345]],
#
#        [[704, 351]],
#
#        [[707, 354]],
#
#        [[707, 355]],
#
#        [[713, 361]],
#
#        [[713, 362]],
#
#        [[714, 363]],
#
#        [[715, 363]],
#
#        [[717, 365]],
#
#        [[717, 366]],
#
#        [[718, 366]],
#
#        [[719, 367]],
#
#        [[720, 367]],
#
#        [[722, 369]],
#
#        [[723, 369]],
#
#        [[727, 373]],
#
#        [[729, 373]],
#
#        [[731, 375]],
#
#        [[732, 375]],
#
#        [[733, 376]],
#
#        [[734, 376]],
#
#        [[735, 377]],
#
#        [[736, 377]],
#
#        [[737, 378]],
#
#        [[739, 378]],
#
#        [[740, 379]],
#
#        [[743, 379]],
#
#        [[744, 380]],
#
#        [[747, 380]],
#
#        [[748, 381]],
#
#        [[756, 381]],
#
#        [[757, 382]],
#
#        [[766, 382]],
#
#        [[767, 381]],
#
#        [[773, 381]],
#
#        [[774, 380]],
#
#        [[777, 380]],
#
#        [[778, 379]],
#
#        [[781, 379]],
#
#        [[782, 378]],
#
#        [[784, 378]],
#
#        [[785, 377]],
#
#        [[786, 377]],
#
#        [[787, 376]],
#
#        [[789, 376]],
#
#        [[791, 374]],
#
#        [[792, 374]],
#
#        [[793, 373]],
#
#        [[794, 373]],
#
#        [[795, 372]],
#
#        [[796, 372]],
#
#        [[797, 371]],
#
#        [[798, 371]],
#
#        [[799, 370]],
#
#        [[800, 370]],
#
#        [[804, 366]],
#
#        [[805, 366]],
#
#        [[813, 358]],
#
#        [[813, 357]],
#
#        [[817, 353]],
#
#        [[817, 352]],
#
#        [[819, 350]],
#
#        [[819, 349]],
#
#        [[820, 348]],
#
#        [[820, 347]],
#
#        [[821, 346]],
#
#        [[821, 345]],
#
#        [[823, 343]],
#
#        [[823, 342]],
#
#        [[824, 341]],
#
#        [[824, 339]],
#
#        [[825, 338]],
#
#        [[825, 337]],
#
#        [[826, 336]],
#
#        [[826, 333]],
#
#        [[827, 332]],
#
#        [[827, 330]],
#
#        [[828, 329]],
#
#        [[828, 325]],
#
#        [[829, 324]],
#
#        [[829, 302]],
#
#        [[828, 301]],
#
#        [[828, 297]],
#
#        [[827, 296]],
#
#        [[827, 294]],
#
#        [[826, 293]],
#
#        [[826, 291]],
#
#        [[825, 290]],
#
#        [[825, 288]],
#
#        [[824, 287]],
#
#        [[824, 286]],
#
#        [[823, 285]],
#
#        [[823, 284]],
#
#        [[822, 283]],
#
#        [[822, 282]],
#
#        [[821, 281]],
#
#        [[821, 280]],
#
#        [[820, 279]],
#
#        [[820, 278]],
#
#        [[818, 276]],
#
#        [[818, 275]],
#
#        [[816, 273]],
#
#        [[816, 272]],
#
#        [[813, 269]],
#
#        [[813, 268]],
#
#        [[812, 268]],
#
#        [[809, 265]],
#
#        [[809, 264]],
#
#        [[808, 263]],
#
#        [[807, 263]],
#
#        [[802, 258]],
#
#        [[801, 258]],
#
#        [[799, 256]],
#
#        [[798, 256]],
#
#        [[797, 255]],
#
#        [[796, 255]],
#
#        [[794, 253]],
#
#        [[793, 253]],
#
#        [[792, 252]],
#
#        [[791, 252]],
#
#        [[790, 251]],
#
#        [[788, 251]],
#
#        [[787, 250]],
#
#        [[786, 250]],
#
#        [[785, 249]],
#
#        [[783, 249]],
#
#        [[782, 248]],
#
#        [[780, 248]],
#
#        [[779, 247]],
#
#        [[776, 247]],
#
#        [[775, 246]],
#
#        [[768, 246]],
#
#        [[767, 245]]], dtype=int32), array([[[379, 203]],
#
#        [[380, 203]]], dtype=int32), array([[[364, 203]],
#
#        [[363, 204]],
#
#        [[362, 204]],
#
#        [[361, 205]],
#
#        [[357, 205]],
#
#        [[356, 206]],
#
#        [[351, 206]],
#
#        [[349, 208]],
#
#        [[348, 208]],
#
#        [[347, 209]],
#
#        [[345, 209]],
#
#        [[344, 210]],
#
#        [[343, 210]],
#
#        [[342, 211]],
#
#        [[341, 211]],
#
#        [[338, 214]],
#
#        [[337, 214]],
#
#        [[336, 215]],
#
#        [[335, 215]],
#
#        [[326, 224]],
#
#        [[326, 225]],
#
#        [[323, 228]],
#
#        [[323, 229]],
#
#        [[321, 231]],
#
#        [[321, 232]],
#
#        [[320, 233]],
#
#        [[320, 234]],
#
#        [[318, 236]],
#
#        [[318, 238]],
#
#        [[317, 239]],
#
#        [[317, 240]],
#
#        [[316, 241]],
#
#        [[316, 243]],
#
#        [[315, 244]],
#
#        [[315, 247]],
#
#        [[314, 248]],
#
#        [[314, 252]],
#
#        [[313, 253]],
#
#        [[313, 268]],
#
#        [[314, 269]],
#
#        [[314, 273]],
#
#        [[315, 274]],
#
#        [[315, 278]],
#
#        [[316, 279]],
#
#        [[316, 282]],
#
#        [[317, 283]],
#
#        [[317, 284]],
#
#        [[318, 285]],
#
#        [[318, 287]],
#
#        [[319, 288]],
#
#        [[319, 289]],
#
#        [[320, 290]],
#
#        [[320, 291]],
#
#        [[322, 293]],
#
#        [[322, 294]],
#
#        [[324, 296]],
#
#        [[324, 297]],
#
#        [[327, 300]],
#
#        [[327, 301]],
#
#        [[336, 310]],
#
#        [[337, 310]],
#
#        [[339, 312]],
#
#        [[340, 312]],
#
#        [[342, 314]],
#
#        [[343, 314]],
#
#        [[345, 316]],
#
#        [[346, 316]],
#
#        [[347, 317]],
#
#        [[349, 317]],
#
#        [[350, 318]],
#
#        [[354, 318]],
#
#        [[355, 319]],
#
#        [[361, 319]],
#
#        [[362, 320]],
#
#        [[361, 319]],
#
#        [[362, 318]],
#
#        [[374, 318]],
#
#        [[375, 317]],
#
#        [[378, 317]],
#
#        [[379, 316]],
#
#        [[384, 316]],
#
#        [[385, 315]],
#
#        [[388, 315]],
#
#        [[389, 314]],
#
#        [[392, 314]],
#
#        [[393, 313]],
#
#        [[395, 313]],
#
#        [[396, 312]],
#
#        [[397, 312]],
#
#        [[398, 311]],
#
#        [[399, 311]],
#
#        [[400, 310]],
#
#        [[401, 310]],
#
#        [[402, 309]],
#
#        [[403, 309]],
#
#        [[405, 307]],
#
#        [[406, 307]],
#
#        [[410, 303]],
#
#        [[411, 303]],
#
#        [[412, 302]],
#
#        [[413, 303]],
#
#        [[413, 304]],
#
#        [[410, 307]],
#
#        [[410, 308]],
#
#        [[408, 310]],
#
#        [[407, 310]],
#
#        [[402, 315]],
#
#        [[399, 315]],
#
#        [[398, 316]],
#
#        [[397, 316]],
#
#        [[397, 317]],
#
#        [[400, 317]],
#
#        [[402, 315]],
#
#        [[403, 315]],
#
#        [[404, 314]],
#
#        [[405, 314]],
#
#        [[407, 312]],
#
#        [[408, 312]],
#
#        [[411, 309]],
#
#        [[412, 309]],
#
#        [[417, 304]],
#
#        [[418, 304]],
#
#        [[418, 303]],
#
#        [[422, 299]],
#
#        [[422, 298]],
#
#        [[425, 295]],
#
#        [[425, 294]],
#
#        [[426, 293]],
#
#        [[426, 292]],
#
#        [[427, 291]],
#
#        [[427, 290]],
#
#        [[428, 289]],
#
#        [[428, 288]],
#
#        [[429, 287]],
#
#        [[429, 286]],
#
#        [[430, 285]],
#
#        [[430, 284]],
#
#        [[431, 283]],
#
#        [[431, 281]],
#
#        [[432, 280]],
#
#        [[432, 276]],
#
#        [[433, 275]],
#
#        [[433, 270]],
#
#        [[434, 269]],
#
#        [[434, 260]],
#
#        [[433, 259]],
#
#        [[433, 253]],
#
#        [[432, 252]],
#
#        [[432, 250]],
#
#        [[431, 249]],
#
#        [[431, 247]],
#
#        [[430, 246]],
#
#        [[430, 243]],
#
#        [[429, 242]],
#
#        [[429, 241]],
#
#        [[427, 239]],
#
#        [[427, 236]],
#
#        [[426, 235]],
#
#        [[426, 234]],
#
#        [[425, 233]],
#
#        [[425, 232]],
#
#        [[422, 229]],
#
#        [[422, 228]],
#
#        [[420, 226]],
#
#        [[420, 225]],
#
#        [[411, 216]],
#
#        [[410, 216]],
#
#        [[407, 213]],
#
#        [[406, 213]],
#
#        [[404, 211]],
#
#        [[403, 211]],
#
#        [[402, 210]],
#
#        [[401, 210]],
#
#        [[400, 209]],
#
#        [[399, 209]],
#
#        [[398, 208]],
#
#        [[397, 208]],
#
#        [[396, 207]],
#
#        [[394, 207]],
#
#        [[393, 206]],
#
#        [[391, 206]],
#
#        [[390, 205]],
#
#        [[388, 205]],
#
#        [[387, 204]],
#
#        [[385, 204]],
#
#        [[386, 205]],
#
#        [[387, 205]],
#
#        [[389, 207]],
#
#        [[387, 209]],
#
#        [[386, 208]],
#
#        [[383, 208]],
#
#        [[382, 207]],
#
#        [[379, 207]],
#
#        [[378, 206]],
#
#        [[375, 206]],
#
#        [[374, 205]],
#
#        [[372, 205]],
#
#        [[371, 204]],
#
#        [[371, 203]]], dtype=int32), array([[[617, 174]],
#
#        [[616, 175]],
#
#        [[611, 175]],
#
#        [[610, 176]],
#
#        [[606, 176]],
#
#        [[605, 177]],
#
#        [[604, 177]],
#
#        [[603, 178]],
#
#        [[601, 178]],
#
#        [[600, 179]],
#
#        [[598, 179]],
#
#        [[597, 180]],
#
#        [[596, 180]],
#
#        [[594, 182]],
#
#        [[592, 182]],
#
#        [[590, 184]],
#
#        [[589, 184]],
#
#        [[587, 186]],
#
#        [[586, 186]],
#
#        [[582, 190]],
#
#        [[581, 190]],
#
#        [[579, 192]],
#
#        [[579, 193]],
#
#        [[577, 195]],
#
#        [[576, 195]],
#
#        [[575, 196]],
#
#        [[575, 197]],
#
#        [[572, 200]],
#
#        [[572, 201]],
#
#        [[569, 204]],
#
#        [[569, 205]],
#
#        [[567, 207]],
#
#        [[567, 209]],
#
#        [[566, 210]],
#
#        [[566, 211]],
#
#        [[564, 213]],
#
#        [[564, 215]],
#
#        [[563, 216]],
#
#        [[563, 217]],
#
#        [[562, 218]],
#
#        [[562, 221]],
#
#        [[561, 222]],
#
#        [[561, 225]],
#
#        [[560, 226]],
#
#        [[560, 229]],
#
#        [[559, 230]],
#
#        [[559, 250]],
#
#        [[560, 251]],
#
#        [[560, 254]],
#
#        [[561, 255]],
#
#        [[561, 258]],
#
#        [[562, 259]],
#
#        [[562, 261]],
#
#        [[563, 262]],
#
#        [[563, 264]],
#
#        [[564, 265]],
#
#        [[564, 266]],
#
#        [[565, 267]],
#
#        [[565, 269]],
#
#        [[566, 270]],
#
#        [[566, 271]],
#
#        [[567, 272]],
#
#        [[567, 273]],
#
#        [[569, 275]],
#
#        [[569, 276]],
#
#        [[572, 279]],
#
#        [[572, 280]],
#
#        [[574, 282]],
#
#        [[574, 283]],
#
#        [[579, 288]],
#
#        [[580, 288]],
#
#        [[582, 290]],
#
#        [[583, 290]],
#
#        [[587, 294]],
#
#        [[588, 294]],
#
#        [[590, 296]],
#
#        [[591, 296]],
#
#        [[592, 297]],
#
#        [[594, 297]],
#
#        [[595, 298]],
#
#        [[596, 298]],
#
#        [[598, 300]],
#
#        [[599, 300]],
#
#        [[600, 301]],
#
#        [[601, 301]],
#
#        [[602, 302]],
#
#        [[604, 302]],
#
#        [[605, 303]],
#
#        [[610, 303]],
#
#        [[611, 304]],
#
#        [[614, 304]],
#
#        [[615, 305]],
#
#        [[627, 305]],
#
#        [[628, 304]],
#
#        [[632, 304]],
#
#        [[633, 303]],
#
#        [[637, 303]],
#
#        [[638, 302]],
#
#        [[641, 302]],
#
#        [[642, 301]],
#
#        [[643, 301]],
#
#        [[644, 300]],
#
#        [[646, 300]],
#
#        [[647, 299]],
#
#        [[648, 299]],
#
#        [[650, 297]],
#
#        [[652, 297]],
#
#        [[653, 296]],
#
#        [[655, 296]],
#
#        [[661, 290]],
#
#        [[663, 290]],
#
#        [[674, 279]],
#
#        [[674, 278]],
#
#        [[678, 274]],
#
#        [[678, 273]],
#
#        [[679, 272]],
#
#        [[679, 271]],
#
#        [[680, 270]],
#
#        [[680, 269]],
#
#        [[681, 268]],
#
#        [[681, 267]],
#
#        [[682, 266]],
#
#        [[682, 265]],
#
#        [[683, 264]],
#
#        [[683, 262]],
#
#        [[684, 261]],
#
#        [[684, 259]],
#
#        [[685, 258]],
#
#        [[685, 256]],
#
#        [[686, 255]],
#
#        [[686, 251]],
#
#        [[687, 250]],
#
#        [[687, 232]],
#
#        [[686, 231]],
#
#        [[686, 230]],
#
#        [[685, 229]],
#
#        [[685, 226]],
#
#        [[684, 225]],
#
#        [[684, 221]],
#
#        [[683, 220]],
#
#        [[683, 216]],
#
#        [[682, 215]],
#
#        [[682, 214]],
#
#        [[681, 213]],
#
#        [[681, 210]],
#
#        [[679, 208]],
#
#        [[679, 207]],
#
#        [[678, 206]],
#
#        [[678, 205]],
#
#        [[677, 204]],
#
#        [[677, 203]],
#
#        [[675, 201]],
#
#        [[675, 200]],
#
#        [[672, 197]],
#
#        [[672, 196]],
#
#        [[664, 188]],
#
#        [[663, 188]],
#
#        [[660, 185]],
#
#        [[659, 185]],
#
#        [[657, 183]],
#
#        [[656, 183]],
#
#        [[655, 182]],
#
#        [[654, 182]],
#
#        [[653, 181]],
#
#        [[652, 181]],
#
#        [[651, 180]],
#
#        [[650, 180]],
#
#        [[649, 179]],
#
#        [[648, 179]],
#
#        [[647, 178]],
#
#        [[645, 178]],
#
#        [[644, 177]],
#
#        [[642, 177]],
#
#        [[641, 176]],
#
#        [[637, 176]],
#
#        [[636, 175]],
#
#        [[633, 175]],
#
#        [[632, 174]]], dtype=int32)]

# %%
# make a copy of the image
contour_image = np.copy(image)

# %%
# declare minimum area and an empty list
minimum_area = 60
large_contours = []

# loop to find large contours
for contour in coin_contours:
    if cv2.contourArea(contour) > minimum_area:
        large_contours.append(contour)

print(large_contours)
# Out:
# [array([[[548, 559]],
#
#        [[547, 560]],
#
#        [[543, 560]],
#
#        [[542, 561]],
#
#        [[539, 561]],
#
#        [[538, 562]],
#
#        [[536, 562]],
#
#        [[535, 563]],
#
#        [[534, 563]],
#
#        [[533, 564]],
#
#        [[532, 564]],
#
#        [[531, 565]],
#
#        [[530, 565]],
#
#        [[529, 566]],
#
#        [[527, 566]],
#
#        [[526, 567]],
#
#        [[525, 567]],
#
#        [[524, 568]],
#
#        [[523, 568]],
#
#        [[519, 572]],
#
#        [[518, 572]],
#
#        [[510, 580]],
#
#        [[510, 581]],
#
#        [[507, 584]],
#
#        [[507, 585]],
#
#        [[505, 587]],
#
#        [[505, 588]],
#
#        [[504, 589]],
#
#        [[504, 590]],
#
#        [[502, 592]],
#
#        [[502, 594]],
#
#        [[501, 595]],
#
#        [[501, 596]],
#
#        [[500, 597]],
#
#        [[500, 598]],
#
#        [[499, 599]],
#
#        [[499, 601]],
#
#        [[498, 602]],
#
#        [[498, 604]],
#
#        [[497, 605]],
#
#        [[497, 608]],
#
#        [[496, 609]],
#
#        [[496, 615]],
#
#        [[495, 616]],
#
#        [[495, 627]],
#
#        [[496, 628]],
#
#        [[496, 634]],
#
#        [[497, 635]],
#
#        [[497, 638]],
#
#        [[498, 639]],
#
#        [[498, 641]],
#
#        [[499, 642]],
#
#        [[499, 644]],
#
#        [[500, 645]],
#
#        [[500, 646]],
#
#        [[501, 647]],
#
#        [[501, 649]],
#
#        [[503, 651]],
#
#        [[503, 653]],
#
#        [[504, 654]],
#
#        [[504, 655]],
#
#        [[506, 657]],
#
#        [[506, 658]],
#
#        [[508, 660]],
#
#        [[509, 660]],
#
#        [[510, 661]],
#
#        [[511, 661]],
#
#        [[512, 662]],
#
#        [[512, 664]],
#
#        [[520, 672]],
#
#        [[521, 672]],
#
#        [[525, 676]],
#
#        [[526, 676]],
#
#        [[528, 678]],
#
#        [[530, 678]],
#
#        [[532, 680]],
#
#        [[533, 680]],
#
#        [[534, 681]],
#
#        [[536, 681]],
#
#        [[537, 682]],
#
#        [[539, 682]],
#
#        [[540, 683]],
#
#        [[543, 683]],
#
#        [[544, 684]],
#
#        [[548, 684]],
#
#        [[549, 685]],
#
#        [[565, 685]],
#
#        [[566, 684]],
#
#        [[570, 684]],
#
#        [[571, 683]],
#
#        [[574, 683]],
#
#        [[575, 682]],
#
#        [[576, 682]],
#
#        [[577, 681]],
#
#        [[579, 681]],
#
#        [[580, 680]],
#
#        [[582, 680]],
#
#        [[583, 679]],
#
#        [[584, 679]],
#
#        [[585, 678]],
#
#        [[586, 678]],
#
#        [[587, 677]],
#
#        [[588, 677]],
#
#        [[590, 675]],
#
#        [[591, 675]],
#
#        [[593, 673]],
#
#        [[594, 673]],
#
#        [[600, 667]],
#
#        [[601, 667]],
#
#        [[602, 666]],
#
#        [[602, 665]],
#
#        [[607, 660]],
#
#        [[607, 659]],
#
#        [[609, 657]],
#
#        [[609, 656]],
#
#        [[611, 654]],
#
#        [[611, 652]],
#
#        [[613, 650]],
#
#        [[613, 649]],
#
#        [[614, 648]],
#
#        [[614, 646]],
#
#        [[615, 645]],
#
#        [[615, 644]],
#
#        [[616, 643]],
#
#        [[616, 642]],
#
#        [[617, 641]],
#
#        [[617, 638]],
#
#        [[618, 637]],
#
#        [[618, 634]],
#
#        [[619, 633]],
#
#        [[619, 628]],
#
#        [[620, 627]],
#
#        [[620, 617]],
#
#        [[619, 616]],
#
#        [[619, 610]],
#
#        [[618, 609]],
#
#        [[618, 606]],
#
#        [[617, 605]],
#
#        [[617, 603]],
#
#        [[616, 602]],
#
#        [[616, 600]],
#
#        [[615, 599]],
#
#        [[615, 598]],
#
#        [[614, 597]],
#
#        [[614, 596]],
#
#        [[613, 595]],
#
#        [[613, 594]],
#
#        [[612, 593]],
#
#        [[612, 592]],
#
#        [[611, 591]],
#
#        [[611, 590]],
#
#        [[610, 589]],
#
#        [[609, 589]],
#
#        [[608, 588]],
#
#        [[608, 586]],
#
#        [[605, 583]],
#
#        [[605, 582]],
#
#        [[604, 581]],
#
#        [[604, 580]],
#
#        [[598, 574]],
#
#        [[597, 574]],
#
#        [[596, 573]],
#
#        [[596, 572]],
#
#        [[595, 572]],
#
#        [[593, 570]],
#
#        [[592, 570]],
#
#        [[590, 568]],
#
#        [[589, 568]],
#
#        [[587, 566]],
#
#        [[586, 566]],
#
#        [[585, 565]],
#
#        [[584, 565]],
#
#        [[583, 564]],
#
#        [[582, 564]],
#
#        [[581, 563]],
#
#        [[579, 563]],
#
#        [[578, 562]],
#
#        [[576, 562]],
#
#        [[575, 561]],
#
#        [[573, 561]],
#
#        [[572, 560]],
#
#        [[568, 560]],
#
#        [[567, 559]]], dtype=int32), array([[[334, 497]],
#
#        [[333, 498]],
#
#        [[323, 498]],
#
#        [[322, 499]],
#
#        [[317, 499]],
#
#        [[316, 500]],
#
#        [[315, 500]],
#
#        [[315, 501]],
#
#        [[313, 503]],
#
#        [[311, 503]],
#
#        [[310, 502]],
#
#        [[309, 502]],
#
#        [[308, 503]],
#
#        [[306, 503]],
#
#        [[305, 504]],
#
#        [[304, 504]],
#
#        [[303, 505]],
#
#        [[302, 505]],
#
#        [[301, 506]],
#
#        [[300, 506]],
#
#        [[298, 508]],
#
#        [[297, 508]],
#
#        [[296, 509]],
#
#        [[295, 509]],
#
#        [[292, 512]],
#
#        [[291, 512]],
#
#        [[283, 520]],
#
#        [[283, 521]],
#
#        [[279, 525]],
#
#        [[279, 526]],
#
#        [[277, 528]],
#
#        [[277, 529]],
#
#        [[275, 531]],
#
#        [[275, 532]],
#
#        [[274, 533]],
#
#        [[274, 534]],
#
#        [[273, 535]],
#
#        [[273, 536]],
#
#        [[272, 537]],
#
#        [[272, 538]],
#
#        [[271, 539]],
#
#        [[271, 540]],
#
#        [[270, 541]],
#
#        [[270, 544]],
#
#        [[269, 545]],
#
#        [[269, 547]],
#
#        [[268, 548]],
#
#        [[268, 551]],
#
#        [[267, 552]],
#
#        [[267, 558]],
#
#        [[266, 559]],
#
#        [[266, 567]],
#
#        [[267, 568]],
#
#        [[267, 576]],
#
#        [[268, 577]],
#
#        [[268, 580]],
#
#        [[269, 581]],
#
#        [[269, 583]],
#
#        [[270, 584]],
#
#        [[270, 586]],
#
#        [[271, 587]],
#
#        [[271, 589]],
#
#        [[272, 590]],
#
#        [[272, 591]],
#
#        [[273, 592]],
#
#        [[273, 593]],
#
#        [[275, 595]],
#
#        [[275, 596]],
#
#        [[276, 597]],
#
#        [[276, 598]],
#
#        [[278, 600]],
#
#        [[278, 601]],
#
#        [[281, 604]],
#
#        [[281, 605]],
#
#        [[287, 611]],
#
#        [[288, 611]],
#
#        [[292, 615]],
#
#        [[293, 615]],
#
#        [[295, 617]],
#
#        [[296, 617]],
#
#        [[298, 619]],
#
#        [[299, 619]],
#
#        [[300, 620]],
#
#        [[301, 620]],
#
#        [[302, 621]],
#
#        [[304, 621]],
#
#        [[305, 622]],
#
#        [[306, 622]],
#
#        [[307, 623]],
#
#        [[309, 623]],
#
#        [[310, 624]],
#
#        [[312, 624]],
#
#        [[313, 625]],
#
#        [[314, 625]],
#
#        [[315, 626]],
#
#        [[320, 626]],
#
#        [[321, 627]],
#
#        [[328, 627]],
#
#        [[329, 628]],
#
#        [[333, 628]],
#
#        [[334, 627]],
#
#        [[342, 627]],
#
#        [[343, 626]],
#
#        [[347, 626]],
#
#        [[348, 625]],
#
#        [[350, 625]],
#
#        [[351, 624]],
#
#        [[353, 624]],
#
#        [[354, 623]],
#
#        [[356, 623]],
#
#        [[357, 622]],
#
#        [[358, 622]],
#
#        [[359, 621]],
#
#        [[361, 621]],
#
#        [[362, 620]],
#
#        [[363, 620]],
#
#        [[365, 618]],
#
#        [[366, 618]],
#
#        [[368, 616]],
#
#        [[369, 616]],
#
#        [[372, 613]],
#
#        [[373, 613]],
#
#        [[384, 602]],
#
#        [[384, 601]],
#
#        [[386, 599]],
#
#        [[386, 598]],
#
#        [[388, 596]],
#
#        [[388, 595]],
#
#        [[389, 594]],
#
#        [[389, 593]],
#
#        [[390, 592]],
#
#        [[390, 591]],
#
#        [[392, 589]],
#
#        [[392, 588]],
#
#        [[393, 587]],
#
#        [[393, 585]],
#
#        [[394, 584]],
#
#        [[394, 582]],
#
#        [[395, 581]],
#
#        [[395, 579]],
#
#        [[396, 578]],
#
#        [[396, 576]],
#
#        [[397, 575]],
#
#        [[397, 572]],
#
#        [[398, 571]],
#
#        [[398, 553]],
#
#        [[397, 552]],
#
#        [[397, 547]],
#
#        [[396, 546]],
#
#        [[396, 544]],
#
#        [[395, 543]],
#
#        [[395, 541]],
#
#        [[394, 540]],
#
#        [[394, 538]],
#
#        [[393, 537]],
#
#        [[393, 536]],
#
#        [[392, 535]],
#
#        [[392, 534]],
#
#        [[391, 533]],
#
#        [[391, 532]],
#
#        [[390, 531]],
#
#        [[390, 530]],
#
#        [[388, 528]],
#
#        [[388, 527]],
#
#        [[387, 526]],
#
#        [[387, 525]],
#
#        [[382, 520]],
#
#        [[382, 519]],
#
#        [[378, 515]],
#
#        [[377, 515]],
#
#        [[372, 510]],
#
#        [[371, 510]],
#
#        [[369, 508]],
#
#        [[368, 508]],
#
#        [[366, 506]],
#
#        [[365, 506]],
#
#        [[364, 505]],
#
#        [[363, 505]],
#
#        [[362, 504]],
#
#        [[361, 504]],
#
#        [[360, 503]],
#
#        [[358, 503]],
#
#        [[357, 502]],
#
#        [[356, 502]],
#
#        [[355, 501]],
#
#        [[353, 501]],
#
#        [[352, 500]],
#
#        [[350, 500]],
#
#        [[349, 499]],
#
#        [[344, 499]],
#
#        [[343, 498]],
#
#        [[342, 498]],
#
#        [[341, 497]]], dtype=int32), array([[[631, 370]],
#
#        [[630, 371]],
#
#        [[625, 371]],
#
#        [[624, 372]],
#
#        [[622, 372]],
#
#        [[621, 373]],
#
#        [[618, 373]],
#
#        [[617, 374]],
#
#        [[615, 374]],
#
#        [[614, 375]],
#
#        [[612, 375]],
#
#        [[611, 376]],
#
#        [[610, 376]],
#
#        [[609, 377]],
#
#        [[608, 377]],
#
#        [[607, 378]],
#
#        [[606, 378]],
#
#        [[606, 379]],
#
#        [[605, 380]],
#
#        [[604, 380]],
#
#        [[603, 379]],
#
#        [[602, 380]],
#
#        [[601, 380]],
#
#        [[600, 381]],
#
#        [[599, 381]],
#
#        [[597, 383]],
#
#        [[595, 383]],
#
#        [[591, 387]],
#
#        [[590, 387]],
#
#        [[588, 389]],
#
#        [[588, 393]],
#
#        [[587, 394]],
#
#        [[586, 394]],
#
#        [[585, 395]],
#
#        [[584, 394]],
#
#        [[583, 394]],
#
#        [[577, 400]],
#
#        [[577, 401]],
#
#        [[575, 403]],
#
#        [[575, 404]],
#
#        [[572, 407]],
#
#        [[572, 408]],
#
#        [[571, 409]],
#
#        [[571, 410]],
#
#        [[570, 411]],
#
#        [[570, 412]],
#
#        [[569, 413]],
#
#        [[569, 414]],
#
#        [[568, 415]],
#
#        [[568, 416]],
#
#        [[567, 417]],
#
#        [[567, 418]],
#
#        [[566, 419]],
#
#        [[566, 421]],
#
#        [[565, 422]],
#
#        [[565, 424]],
#
#        [[564, 425]],
#
#        [[564, 427]],
#
#        [[563, 428]],
#
#        [[563, 431]],
#
#        [[562, 432]],
#
#        [[562, 435]],
#
#        [[561, 436]],
#
#        [[561, 446]],
#
#        [[560, 447]],
#
#        [[560, 454]],
#
#        [[561, 455]],
#
#        [[561, 461]],
#
#        [[562, 462]],
#
#        [[562, 466]],
#
#        [[563, 467]],
#
#        [[563, 470]],
#
#        [[564, 471]],
#
#        [[564, 473]],
#
#        [[565, 474]],
#
#        [[565, 476]],
#
#        [[566, 477]],
#
#        [[566, 479]],
#
#        [[567, 480]],
#
#        [[567, 481]],
#
#        [[568, 482]],
#
#        [[568, 484]],
#
#        [[569, 485]],
#
#        [[569, 486]],
#
#        [[571, 488]],
#
#        [[571, 489]],
#
#        [[572, 490]],
#
#        [[572, 491]],
#
#        [[574, 493]],
#
#        [[574, 494]],
#
#        [[576, 496]],
#
#        [[576, 497]],
#
#        [[577, 498]],
#
#        [[578, 498]],
#
#        [[579, 499]],
#
#        [[579, 500]],
#
#        [[583, 504]],
#
#        [[584, 504]],
#
#        [[593, 513]],
#
#        [[594, 513]],
#
#        [[598, 517]],
#
#        [[599, 517]],
#
#        [[602, 520]],
#
#        [[603, 520]],
#
#        [[604, 521]],
#
#        [[605, 521]],
#
#        [[606, 522]],
#
#        [[608, 522]],
#
#        [[609, 523]],
#
#        [[610, 523]],
#
#        [[611, 524]],
#
#        [[612, 524]],
#
#        [[613, 525]],
#
#        [[615, 525]],
#
#        [[616, 526]],
#
#        [[619, 526]],
#
#        [[620, 527]],
#
#        [[622, 527]],
#
#        [[623, 528]],
#
#        [[627, 528]],
#
#        [[628, 529]],
#
#        [[646, 529]],
#
#        [[647, 528]],
#
#        [[652, 528]],
#
#        [[653, 527]],
#
#        [[659, 527]],
#
#        [[660, 526]],
#
#        [[662, 526]],
#
#        [[663, 525]],
#
#        [[664, 525]],
#
#        [[665, 524]],
#
#        [[668, 524]],
#
#        [[669, 523]],
#
#        [[671, 523]],
#
#        [[672, 522]],
#
#        [[673, 522]],
#
#        [[674, 521]],
#
#        [[675, 521]],
#
#        [[676, 520]],
#
#        [[677, 520]],
#
#        [[678, 519]],
#
#        [[679, 519]],
#
#        [[681, 517]],
#
#        [[682, 517]],
#
#        [[683, 516]],
#
#        [[684, 516]],
#
#        [[686, 514]],
#
#        [[687, 514]],
#
#        [[691, 510]],
#
#        [[692, 510]],
#
#        [[696, 506]],
#
#        [[696, 505]],
#
#        [[697, 504]],
#
#        [[698, 504]],
#
#        [[700, 502]],
#
#        [[700, 501]],
#
#        [[704, 497]],
#
#        [[704, 496]],
#
#        [[708, 492]],
#
#        [[708, 491]],
#
#        [[709, 490]],
#
#        [[709, 489]],
#
#        [[710, 488]],
#
#        [[710, 487]],
#
#        [[711, 486]],
#
#        [[711, 485]],
#
#        [[712, 484]],
#
#        [[712, 483]],
#
#        [[713, 482]],
#
#        [[713, 481]],
#
#        [[714, 480]],
#
#        [[714, 479]],
#
#        [[715, 478]],
#
#        [[715, 476]],
#
#        [[716, 475]],
#
#        [[716, 473]],
#
#        [[717, 472]],
#
#        [[717, 469]],
#
#        [[718, 468]],
#
#        [[718, 464]],
#
#        [[719, 463]],
#
#        [[719, 456]],
#
#        [[720, 455]],
#
#        [[720, 448]],
#
#        [[719, 447]],
#
#        [[719, 436]],
#
#        [[718, 435]],
#
#        [[718, 432]],
#
#        [[717, 431]],
#
#        [[717, 428]],
#
#        [[716, 427]],
#
#        [[716, 425]],
#
#        [[715, 424]],
#
#        [[715, 422]],
#
#        [[714, 421]],
#
#        [[714, 419]],
#
#        [[713, 418]],
#
#        [[713, 417]],
#
#        [[712, 416]],
#
#        [[712, 415]],
#
#        [[709, 412]],
#
#        [[709, 411]],
#
#        [[708, 410]],
#
#        [[708, 408]],
#
#        [[706, 406]],
#
#        [[706, 405]],
#
#        [[705, 404]],
#
#        [[705, 403]],
#
#        [[700, 398]],
#
#        [[700, 397]],
#
#        [[691, 388]],
#
#        [[690, 388]],
#
#        [[687, 385]],
#
#        [[686, 385]],
#
#        [[684, 383]],
#
#        [[683, 383]],
#
#        [[681, 381]],
#
#        [[680, 381]],
#
#        [[679, 380]],
#
#        [[678, 380]],
#
#        [[676, 378]],
#
#        [[675, 378]],
#
#        [[674, 377]],
#
#        [[672, 377]],
#
#        [[671, 376]],
#
#        [[670, 376]],
#
#        [[669, 375]],
#
#        [[667, 375]],
#
#        [[666, 374]],
#
#        [[665, 374]],
#
#        [[664, 373]],
#
#        [[661, 373]],
#
#        [[660, 372]],
#
#        [[657, 372]],
#
#        [[656, 371]],
#
#        [[649, 371]],
#
#        [[648, 370]]], dtype=int32), array([[[449, 365]],
#
#        [[448, 366]],
#
#        [[444, 366]],
#
#        [[443, 367]],
#
#        [[442, 367]],
#
#        [[441, 368]],
#
#        [[440, 368]],
#
#        [[439, 369]],
#
#        [[435, 369]],
#
#        [[434, 370]],
#
#        [[432, 370]],
#
#        [[431, 371]],
#
#        [[430, 371]],
#
#        [[428, 373]],
#
#        [[426, 373]],
#
#        [[425, 374]],
#
#        [[424, 374]],
#
#        [[423, 375]],
#
#        [[422, 375]],
#
#        [[421, 376]],
#
#        [[420, 376]],
#
#        [[416, 380]],
#
#        [[415, 380]],
#
#        [[410, 385]],
#
#        [[409, 385]],
#
#        [[407, 387]],
#
#        [[407, 388]],
#
#        [[404, 391]],
#
#        [[404, 392]],
#
#        [[402, 394]],
#
#        [[402, 395]],
#
#        [[401, 396]],
#
#        [[401, 397]],
#
#        [[399, 399]],
#
#        [[399, 400]],
#
#        [[398, 401]],
#
#        [[398, 402]],
#
#        [[397, 403]],
#
#        [[397, 405]],
#
#        [[396, 406]],
#
#        [[396, 407]],
#
#        [[395, 408]],
#
#        [[395, 410]],
#
#        [[394, 411]],
#
#        [[394, 414]],
#
#        [[393, 415]],
#
#        [[393, 419]],
#
#        [[392, 420]],
#
#        [[392, 437]],
#
#        [[393, 438]],
#
#        [[393, 443]],
#
#        [[394, 444]],
#
#        [[394, 447]],
#
#        [[395, 448]],
#
#        [[395, 449]],
#
#        [[396, 450]],
#
#        [[396, 452]],
#
#        [[397, 453]],
#
#        [[397, 455]],
#
#        [[398, 456]],
#
#        [[398, 457]],
#
#        [[399, 458]],
#
#        [[399, 459]],
#
#        [[400, 460]],
#
#        [[400, 461]],
#
#        [[402, 463]],
#
#        [[402, 464]],
#
#        [[404, 466]],
#
#        [[404, 467]],
#
#        [[408, 471]],
#
#        [[408, 472]],
#
#        [[413, 477]],
#
#        [[414, 477]],
#
#        [[418, 481]],
#
#        [[419, 481]],
#
#        [[421, 483]],
#
#        [[422, 483]],
#
#        [[423, 484]],
#
#        [[424, 484]],
#
#        [[425, 485]],
#
#        [[426, 485]],
#
#        [[427, 486]],
#
#        [[428, 486]],
#
#        [[429, 487]],
#
#        [[430, 487]],
#
#        [[431, 488]],
#
#        [[433, 488]],
#
#        [[434, 489]],
#
#        [[435, 489]],
#
#        [[436, 490]],
#
#        [[438, 490]],
#
#        [[439, 491]],
#
#        [[442, 491]],
#
#        [[443, 492]],
#
#        [[447, 492]],
#
#        [[448, 493]],
#
#        [[464, 493]],
#
#        [[465, 492]],
#
#        [[468, 492]],
#
#        [[468, 490]],
#
#        [[465, 490]],
#
#        [[464, 489]],
#
#        [[465, 488]],
#
#        [[468, 488]],
#
#        [[469, 487]],
#
#        [[470, 487]],
#
#        [[471, 486]],
#
#        [[475, 486]],
#
#        [[476, 485]],
#
#        [[477, 485]],
#
#        [[478, 484]],
#
#        [[479, 484]],
#
#        [[480, 483]],
#
#        [[482, 483]],
#
#        [[483, 484]],
#
#        [[481, 486]],
#
#        [[480, 486]],
#
#        [[479, 487]],
#
#        [[477, 487]],
#
#        [[477, 488]],
#
#        [[476, 489]],
#
#        [[479, 489]],
#
#        [[480, 488]],
#
#        [[481, 488]],
#
#        [[482, 487]],
#
#        [[484, 487]],
#
#        [[485, 486]],
#
#        [[486, 486]],
#
#        [[488, 484]],
#
#        [[489, 484]],
#
#        [[490, 483]],
#
#        [[491, 483]],
#
#        [[493, 481]],
#
#        [[494, 481]],
#
#        [[498, 477]],
#
#        [[499, 477]],
#
#        [[507, 469]],
#
#        [[507, 468]],
#
#        [[509, 466]],
#
#        [[509, 465]],
#
#        [[510, 464]],
#
#        [[510, 463]],
#
#        [[513, 460]],
#
#        [[513, 458]],
#
#        [[515, 456]],
#
#        [[515, 455]],
#
#        [[516, 454]],
#
#        [[516, 452]],
#
#        [[517, 451]],
#
#        [[517, 450]],
#
#        [[518, 449]],
#
#        [[518, 447]],
#
#        [[519, 446]],
#
#        [[519, 444]],
#
#        [[520, 443]],
#
#        [[520, 439]],
#
#        [[521, 438]],
#
#        [[521, 420]],
#
#        [[520, 419]],
#
#        [[520, 415]],
#
#        [[519, 414]],
#
#        [[519, 412]],
#
#        [[518, 411]],
#
#        [[518, 410]],
#
#        [[517, 409]],
#
#        [[517, 407]],
#
#        [[516, 406]],
#
#        [[516, 404]],
#
#        [[514, 402]],
#
#        [[514, 400]],
#
#        [[513, 399]],
#
#        [[513, 398]],
#
#        [[512, 397]],
#
#        [[512, 396]],
#
#        [[510, 394]],
#
#        [[510, 393]],
#
#        [[509, 392]],
#
#        [[509, 391]],
#
#        [[504, 386]],
#
#        [[504, 385]],
#
#        [[499, 380]],
#
#        [[498, 380]],
#
#        [[495, 377]],
#
#        [[494, 377]],
#
#        [[492, 375]],
#
#        [[491, 375]],
#
#        [[489, 373]],
#
#        [[488, 373]],
#
#        [[487, 372]],
#
#        [[486, 372]],
#
#        [[485, 371]],
#
#        [[484, 371]],
#
#        [[483, 370]],
#
#        [[482, 370]],
#
#        [[481, 369]],
#
#        [[479, 369]],
#
#        [[478, 368]],
#
#        [[476, 368]],
#
#        [[475, 367]],
#
#        [[472, 367]],
#
#        [[471, 366]],
#
#        [[467, 366]],
#
#        [[466, 365]]], dtype=int32), array([[[284, 319]],
#
#        [[284, 320]],
#
#        [[285, 321]],
#
#        [[288, 321]],
#
#        [[289, 322]],
#
#        [[290, 322]],
#
#        [[291, 323]],
#
#        [[294, 323]],
#
#        [[296, 325]],
#
#        [[295, 326]],
#
#        [[290, 326]],
#
#        [[289, 325]],
#
#        [[286, 325]],
#
#        [[285, 324]],
#
#        [[278, 324]],
#
#        [[277, 323]],
#
#        [[264, 323]],
#
#        [[263, 322]],
#
#        [[256, 322]],
#
#        [[255, 323]],
#
#        [[249, 323]],
#
#        [[248, 324]],
#
#        [[246, 324]],
#
#        [[245, 325]],
#
#        [[242, 325]],
#
#        [[240, 323]],
#
#        [[240, 322]],
#
#        [[239, 322]],
#
#        [[238, 323]],
#
#        [[236, 323]],
#
#        [[235, 324]],
#
#        [[232, 324]],
#
#        [[231, 325]],
#
#        [[230, 325]],
#
#        [[229, 326]],
#
#        [[228, 326]],
#
#        [[227, 327]],
#
#        [[226, 327]],
#
#        [[225, 328]],
#
#        [[224, 328]],
#
#        [[222, 330]],
#
#        [[221, 330]],
#
#        [[219, 332]],
#
#        [[218, 332]],
#
#        [[213, 337]],
#
#        [[212, 337]],
#
#        [[205, 344]],
#
#        [[205, 345]],
#
#        [[201, 349]],
#
#        [[201, 350]],
#
#        [[199, 352]],
#
#        [[199, 353]],
#
#        [[197, 355]],
#
#        [[197, 356]],
#
#        [[196, 357]],
#
#        [[196, 358]],
#
#        [[194, 360]],
#
#        [[194, 361]],
#
#        [[193, 362]],
#
#        [[193, 364]],
#
#        [[192, 365]],
#
#        [[192, 366]],
#
#        [[191, 367]],
#
#        [[191, 368]],
#
#        [[190, 369]],
#
#        [[190, 372]],
#
#        [[189, 373]],
#
#        [[189, 375]],
#
#        [[188, 376]],
#
#        [[188, 380]],
#
#        [[187, 381]],
#
#        [[187, 388]],
#
#        [[186, 389]],
#
#        [[186, 402]],
#
#        [[187, 403]],
#
#        [[187, 409]],
#
#        [[188, 410]],
#
#        [[188, 414]],
#
#        [[189, 415]],
#
#        [[189, 417]],
#
#        [[190, 418]],
#
#        [[190, 420]],
#
#        [[191, 421]],
#
#        [[191, 423]],
#
#        [[192, 424]],
#
#        [[192, 426]],
#
#        [[193, 427]],
#
#        [[193, 428]],
#
#        [[194, 429]],
#
#        [[194, 430]],
#
#        [[196, 432]],
#
#        [[196, 433]],
#
#        [[197, 434]],
#
#        [[197, 435]],
#
#        [[198, 436]],
#
#        [[198, 437]],
#
#        [[200, 439]],
#
#        [[200, 440]],
#
#        [[203, 443]],
#
#        [[203, 444]],
#
#        [[214, 455]],
#
#        [[215, 455]],
#
#        [[216, 456]],
#
#        [[217, 455]],
#
#        [[218, 455]],
#
#        [[219, 456]],
#
#        [[219, 457]],
#
#        [[218, 458]],
#
#        [[219, 459]],
#
#        [[222, 459]],
#
#        [[223, 460]],
#
#        [[223, 461]],
#
#        [[226, 464]],
#
#        [[227, 464]],
#
#        [[228, 465]],
#
#        [[229, 465]],
#
#        [[230, 466]],
#
#        [[231, 466]],
#
#        [[232, 467]],
#
#        [[234, 467]],
#
#        [[235, 468]],
#
#        [[236, 468]],
#
#        [[237, 469]],
#
#        [[239, 469]],
#
#        [[240, 470]],
#
#        [[241, 470]],
#
#        [[240, 470]],
#
#        [[238, 468]],
#
#        [[237, 468]],
#
#        [[236, 467]],
#
#        [[234, 467]],
#
#        [[233, 466]],
#
#        [[233, 465]],
#
#        [[234, 464]],
#
#        [[236, 464]],
#
#        [[237, 465]],
#
#        [[238, 465]],
#
#        [[239, 466]],
#
#        [[245, 466]],
#
#        [[246, 467]],
#
#        [[248, 467]],
#
#        [[249, 468]],
#
#        [[257, 468]],
#
#        [[258, 469]],
#
#        [[260, 469]],
#
#        [[261, 468]],
#
#        [[263, 468]],
#
#        [[264, 469]],
#
#        [[272, 469]],
#
#        [[273, 468]],
#
#        [[282, 468]],
#
#        [[283, 467]],
#
#        [[285, 467]],
#
#        [[286, 466]],
#
#        [[289, 466]],
#
#        [[290, 465]],
#
#        [[293, 465]],
#
#        [[294, 464]],
#
#        [[295, 464]],
#
#        [[296, 463]],
#
#        [[298, 463]],
#
#        [[299, 462]],
#
#        [[300, 462]],
#
#        [[302, 460]],
#
#        [[304, 460]],
#
#        [[305, 459]],
#
#        [[306, 459]],
#
#        [[307, 458]],
#
#        [[308, 458]],
#
#        [[311, 455]],
#
#        [[312, 455]],
#
#        [[314, 453]],
#
#        [[315, 453]],
#
#        [[321, 447]],
#
#        [[322, 447]],
#
#        [[325, 444]],
#
#        [[326, 445]],
#
#        [[326, 446]],
#
#        [[321, 451]],
#
#        [[321, 452]],
#
#        [[317, 456]],
#
#        [[316, 456]],
#
#        [[311, 461]],
#
#        [[310, 461]],
#
#        [[309, 462]],
#
#        [[307, 462]],
#
#        [[306, 463]],
#
#        [[306, 464]],
#
#        [[307, 464]],
#
#        [[308, 463]],
#
#        [[309, 463]],
#
#        [[311, 461]],
#
#        [[312, 461]],
#
#        [[314, 459]],
#
#        [[315, 459]],
#
#        [[317, 457]],
#
#        [[318, 457]],
#
#        [[327, 448]],
#
#        [[327, 447]],
#
#        [[328, 446]],
#
#        [[326, 444]],
#
#        [[326, 443]],
#
#        [[327, 442]],
#
#        [[331, 442]],
#
#        [[336, 437]],
#
#        [[336, 436]],
#
#        [[337, 435]],
#
#        [[337, 434]],
#
#        [[339, 432]],
#
#        [[339, 431]],
#
#        [[340, 430]],
#
#        [[340, 429]],
#
#        [[341, 428]],
#
#        [[341, 427]],
#
#        [[342, 426]],
#
#        [[342, 425]],
#
#        [[343, 424]],
#
#        [[343, 423]],
#
#        [[344, 422]],
#
#        [[344, 420]],
#
#        [[345, 419]],
#
#        [[345, 418]],
#
#        [[346, 417]],
#
#        [[346, 415]],
#
#        [[347, 414]],
#
#        [[347, 411]],
#
#        [[348, 410]],
#
#        [[348, 407]],
#
#        [[349, 406]],
#
#        [[349, 385]],
#
#        [[348, 384]],
#
#        [[348, 380]],
#
#        [[347, 379]],
#
#        [[347, 377]],
#
#        [[346, 376]],
#
#        [[346, 373]],
#
#        [[345, 372]],
#
#        [[345, 371]],
#
#        [[344, 370]],
#
#        [[344, 368]],
#
#        [[343, 367]],
#
#        [[343, 366]],
#
#        [[342, 365]],
#
#        [[342, 364]],
#
#        [[340, 362]],
#
#        [[340, 361]],
#
#        [[339, 360]],
#
#        [[339, 359]],
#
#        [[338, 358]],
#
#        [[338, 357]],
#
#        [[337, 356]],
#
#        [[337, 355]],
#
#        [[335, 353]],
#
#        [[335, 352]],
#
#        [[333, 350]],
#
#        [[333, 349]],
#
#        [[329, 345]],
#
#        [[329, 344]],
#
#        [[328, 343]],
#
#        [[327, 343]],
#
#        [[326, 342]],
#
#        [[326, 341]],
#
#        [[324, 339]],
#
#        [[323, 339]],
#
#        [[317, 333]],
#
#        [[316, 333]],
#
#        [[314, 331]],
#
#        [[313, 331]],
#
#        [[311, 329]],
#
#        [[310, 329]],
#
#        [[309, 328]],
#
#        [[308, 328]],
#
#        [[307, 327]],
#
#        [[306, 327]],
#
#        [[305, 326]],
#
#        [[304, 326]],
#
#        [[303, 325]],
#
#        [[302, 325]],
#
#        [[301, 324]],
#
#        [[300, 324]],
#
#        [[299, 323]],
#
#        [[297, 323]],
#
#        [[296, 322]],
#
#        [[294, 322]],
#
#        [[293, 321]],
#
#        [[287, 321]],
#
#        [[286, 320]],
#
#        [[285, 320]]], dtype=int32), array([[[760, 245]],
#
#        [[759, 246]],
#
#        [[754, 246]],
#
#        [[753, 247]],
#
#        [[748, 247]],
#
#        [[747, 248]],
#
#        [[744, 248]],
#
#        [[743, 249]],
#
#        [[742, 249]],
#
#        [[741, 250]],
#
#        [[739, 250]],
#
#        [[738, 251]],
#
#        [[736, 251]],
#
#        [[735, 252]],
#
#        [[734, 252]],
#
#        [[733, 253]],
#
#        [[732, 253]],
#
#        [[731, 254]],
#
#        [[730, 254]],
#
#        [[729, 255]],
#
#        [[728, 255]],
#
#        [[727, 256]],
#
#        [[726, 256]],
#
#        [[725, 257]],
#
#        [[724, 257]],
#
#        [[720, 261]],
#
#        [[719, 261]],
#
#        [[712, 268]],
#
#        [[712, 269]],
#
#        [[709, 272]],
#
#        [[709, 273]],
#
#        [[705, 277]],
#
#        [[705, 278]],
#
#        [[704, 279]],
#
#        [[704, 281]],
#
#        [[702, 283]],
#
#        [[701, 283]],
#
#        [[700, 284]],
#
#        [[700, 285]],
#
#        [[699, 286]],
#
#        [[699, 288]],
#
#        [[698, 289]],
#
#        [[698, 291]],
#
#        [[697, 292]],
#
#        [[697, 293]],
#
#        [[696, 294]],
#
#        [[696, 296]],
#
#        [[695, 297]],
#
#        [[695, 301]],
#
#        [[694, 302]],
#
#        [[694, 307]],
#
#        [[693, 308]],
#
#        [[693, 319]],
#
#        [[694, 320]],
#
#        [[694, 326]],
#
#        [[695, 327]],
#
#        [[695, 329]],
#
#        [[697, 329]],
#
#        [[698, 330]],
#
#        [[698, 331]],
#
#        [[697, 332]],
#
#        [[696, 332]],
#
#        [[696, 334]],
#
#        [[697, 335]],
#
#        [[698, 335]],
#
#        [[699, 336]],
#
#        [[701, 336]],
#
#        [[705, 340]],
#
#        [[705, 343]],
#
#        [[704, 344]],
#
#        [[703, 344]],
#
#        [[704, 345]],
#
#        [[704, 351]],
#
#        [[707, 354]],
#
#        [[707, 355]],
#
#        [[713, 361]],
#
#        [[713, 362]],
#
#        [[714, 363]],
#
#        [[715, 363]],
#
#        [[717, 365]],
#
#        [[717, 366]],
#
#        [[718, 366]],
#
#        [[719, 367]],
#
#        [[720, 367]],
#
#        [[722, 369]],
#
#        [[723, 369]],
#
#        [[727, 373]],
#
#        [[729, 373]],
#
#        [[731, 375]],
#
#        [[732, 375]],
#
#        [[733, 376]],
#
#        [[734, 376]],
#
#        [[735, 377]],
#
#        [[736, 377]],
#
#        [[737, 378]],
#
#        [[739, 378]],
#
#        [[740, 379]],
#
#        [[743, 379]],
#
#        [[744, 380]],
#
#        [[747, 380]],
#
#        [[748, 381]],
#
#        [[756, 381]],
#
#        [[757, 382]],
#
#        [[766, 382]],
#
#        [[767, 381]],
#
#        [[773, 381]],
#
#        [[774, 380]],
#
#        [[777, 380]],
#
#        [[778, 379]],
#
#        [[781, 379]],
#
#        [[782, 378]],
#
#        [[784, 378]],
#
#        [[785, 377]],
#
#        [[786, 377]],
#
#        [[787, 376]],
#
#        [[789, 376]],
#
#        [[791, 374]],
#
#        [[792, 374]],
#
#        [[793, 373]],
#
#        [[794, 373]],
#
#        [[795, 372]],
#
#        [[796, 372]],
#
#        [[797, 371]],
#
#        [[798, 371]],
#
#        [[799, 370]],
#
#        [[800, 370]],
#
#        [[804, 366]],
#
#        [[805, 366]],
#
#        [[813, 358]],
#
#        [[813, 357]],
#
#        [[817, 353]],
#
#        [[817, 352]],
#
#        [[819, 350]],
#
#        [[819, 349]],
#
#        [[820, 348]],
#
#        [[820, 347]],
#
#        [[821, 346]],
#
#        [[821, 345]],
#
#        [[823, 343]],
#
#        [[823, 342]],
#
#        [[824, 341]],
#
#        [[824, 339]],
#
#        [[825, 338]],
#
#        [[825, 337]],
#
#        [[826, 336]],
#
#        [[826, 333]],
#
#        [[827, 332]],
#
#        [[827, 330]],
#
#        [[828, 329]],
#
#        [[828, 325]],
#
#        [[829, 324]],
#
#        [[829, 302]],
#
#        [[828, 301]],
#
#        [[828, 297]],
#
#        [[827, 296]],
#
#        [[827, 294]],
#
#        [[826, 293]],
#
#        [[826, 291]],
#
#        [[825, 290]],
#
#        [[825, 288]],
#
#        [[824, 287]],
#
#        [[824, 286]],
#
#        [[823, 285]],
#
#        [[823, 284]],
#
#        [[822, 283]],
#
#        [[822, 282]],
#
#        [[821, 281]],
#
#        [[821, 280]],
#
#        [[820, 279]],
#
#        [[820, 278]],
#
#        [[818, 276]],
#
#        [[818, 275]],
#
#        [[816, 273]],
#
#        [[816, 272]],
#
#        [[813, 269]],
#
#        [[813, 268]],
#
#        [[812, 268]],
#
#        [[809, 265]],
#
#        [[809, 264]],
#
#        [[808, 263]],
#
#        [[807, 263]],
#
#        [[802, 258]],
#
#        [[801, 258]],
#
#        [[799, 256]],
#
#        [[798, 256]],
#
#        [[797, 255]],
#
#        [[796, 255]],
#
#        [[794, 253]],
#
#        [[793, 253]],
#
#        [[792, 252]],
#
#        [[791, 252]],
#
#        [[790, 251]],
#
#        [[788, 251]],
#
#        [[787, 250]],
#
#        [[786, 250]],
#
#        [[785, 249]],
#
#        [[783, 249]],
#
#        [[782, 248]],
#
#        [[780, 248]],
#
#        [[779, 247]],
#
#        [[776, 247]],
#
#        [[775, 246]],
#
#        [[768, 246]],
#
#        [[767, 245]]], dtype=int32), array([[[364, 203]],
#
#        [[363, 204]],
#
#        [[362, 204]],
#
#        [[361, 205]],
#
#        [[357, 205]],
#
#        [[356, 206]],
#
#        [[351, 206]],
#
#        [[349, 208]],
#
#        [[348, 208]],
#
#        [[347, 209]],
#
#        [[345, 209]],
#
#        [[344, 210]],
#
#        [[343, 210]],
#
#        [[342, 211]],
#
#        [[341, 211]],
#
#        [[338, 214]],
#
#        [[337, 214]],
#
#        [[336, 215]],
#
#        [[335, 215]],
#
#        [[326, 224]],
#
#        [[326, 225]],
#
#        [[323, 228]],
#
#        [[323, 229]],
#
#        [[321, 231]],
#
#        [[321, 232]],
#
#        [[320, 233]],
#
#        [[320, 234]],
#
#        [[318, 236]],
#
#        [[318, 238]],
#
#        [[317, 239]],
#
#        [[317, 240]],
#
#        [[316, 241]],
#
#        [[316, 243]],
#
#        [[315, 244]],
#
#        [[315, 247]],
#
#        [[314, 248]],
#
#        [[314, 252]],
#
#        [[313, 253]],
#
#        [[313, 268]],
#
#        [[314, 269]],
#
#        [[314, 273]],
#
#        [[315, 274]],
#
#        [[315, 278]],
#
#        [[316, 279]],
#
#        [[316, 282]],
#
#        [[317, 283]],
#
#        [[317, 284]],
#
#        [[318, 285]],
#
#        [[318, 287]],
#
#        [[319, 288]],
#
#        [[319, 289]],
#
#        [[320, 290]],
#
#        [[320, 291]],
#
#        [[322, 293]],
#
#        [[322, 294]],
#
#        [[324, 296]],
#
#        [[324, 297]],
#
#        [[327, 300]],
#
#        [[327, 301]],
#
#        [[336, 310]],
#
#        [[337, 310]],
#
#        [[339, 312]],
#
#        [[340, 312]],
#
#        [[342, 314]],
#
#        [[343, 314]],
#
#        [[345, 316]],
#
#        [[346, 316]],
#
#        [[347, 317]],
#
#        [[349, 317]],
#
#        [[350, 318]],
#
#        [[354, 318]],
#
#        [[355, 319]],
#
#        [[361, 319]],
#
#        [[362, 320]],
#
#        [[361, 319]],
#
#        [[362, 318]],
#
#        [[374, 318]],
#
#        [[375, 317]],
#
#        [[378, 317]],
#
#        [[379, 316]],
#
#        [[384, 316]],
#
#        [[385, 315]],
#
#        [[388, 315]],
#
#        [[389, 314]],
#
#        [[392, 314]],
#
#        [[393, 313]],
#
#        [[395, 313]],
#
#        [[396, 312]],
#
#        [[397, 312]],
#
#        [[398, 311]],
#
#        [[399, 311]],
#
#        [[400, 310]],
#
#        [[401, 310]],
#
#        [[402, 309]],
#
#        [[403, 309]],
#
#        [[405, 307]],
#
#        [[406, 307]],
#
#        [[410, 303]],
#
#        [[411, 303]],
#
#        [[412, 302]],
#
#        [[413, 303]],
#
#        [[413, 304]],
#
#        [[410, 307]],
#
#        [[410, 308]],
#
#        [[408, 310]],
#
#        [[407, 310]],
#
#        [[402, 315]],
#
#        [[399, 315]],
#
#        [[398, 316]],
#
#        [[397, 316]],
#
#        [[397, 317]],
#
#        [[400, 317]],
#
#        [[402, 315]],
#
#        [[403, 315]],
#
#        [[404, 314]],
#
#        [[405, 314]],
#
#        [[407, 312]],
#
#        [[408, 312]],
#
#        [[411, 309]],
#
#        [[412, 309]],
#
#        [[417, 304]],
#
#        [[418, 304]],
#
#        [[418, 303]],
#
#        [[422, 299]],
#
#        [[422, 298]],
#
#        [[425, 295]],
#
#        [[425, 294]],
#
#        [[426, 293]],
#
#        [[426, 292]],
#
#        [[427, 291]],
#
#        [[427, 290]],
#
#        [[428, 289]],
#
#        [[428, 288]],
#
#        [[429, 287]],
#
#        [[429, 286]],
#
#        [[430, 285]],
#
#        [[430, 284]],
#
#        [[431, 283]],
#
#        [[431, 281]],
#
#        [[432, 280]],
#
#        [[432, 276]],
#
#        [[433, 275]],
#
#        [[433, 270]],
#
#        [[434, 269]],
#
#        [[434, 260]],
#
#        [[433, 259]],
#
#        [[433, 253]],
#
#        [[432, 252]],
#
#        [[432, 250]],
#
#        [[431, 249]],
#
#        [[431, 247]],
#
#        [[430, 246]],
#
#        [[430, 243]],
#
#        [[429, 242]],
#
#        [[429, 241]],
#
#        [[427, 239]],
#
#        [[427, 236]],
#
#        [[426, 235]],
#
#        [[426, 234]],
#
#        [[425, 233]],
#
#        [[425, 232]],
#
#        [[422, 229]],
#
#        [[422, 228]],
#
#        [[420, 226]],
#
#        [[420, 225]],
#
#        [[411, 216]],
#
#        [[410, 216]],
#
#        [[407, 213]],
#
#        [[406, 213]],
#
#        [[404, 211]],
#
#        [[403, 211]],
#
#        [[402, 210]],
#
#        [[401, 210]],
#
#        [[400, 209]],
#
#        [[399, 209]],
#
#        [[398, 208]],
#
#        [[397, 208]],
#
#        [[396, 207]],
#
#        [[394, 207]],
#
#        [[393, 206]],
#
#        [[391, 206]],
#
#        [[390, 205]],
#
#        [[388, 205]],
#
#        [[387, 204]],
#
#        [[385, 204]],
#
#        [[386, 205]],
#
#        [[387, 205]],
#
#        [[389, 207]],
#
#        [[387, 209]],
#
#        [[386, 208]],
#
#        [[383, 208]],
#
#        [[382, 207]],
#
#        [[379, 207]],
#
#        [[378, 206]],
#
#        [[375, 206]],
#
#        [[374, 205]],
#
#        [[372, 205]],
#
#        [[371, 204]],
#
#        [[371, 203]]], dtype=int32), array([[[617, 174]],
#
#        [[616, 175]],
#
#        [[611, 175]],
#
#        [[610, 176]],
#
#        [[606, 176]],
#
#        [[605, 177]],
#
#        [[604, 177]],
#
#        [[603, 178]],
#
#        [[601, 178]],
#
#        [[600, 179]],
#
#        [[598, 179]],
#
#        [[597, 180]],
#
#        [[596, 180]],
#
#        [[594, 182]],
#
#        [[592, 182]],
#
#        [[590, 184]],
#
#        [[589, 184]],
#
#        [[587, 186]],
#
#        [[586, 186]],
#
#        [[582, 190]],
#
#        [[581, 190]],
#
#        [[579, 192]],
#
#        [[579, 193]],
#
#        [[577, 195]],
#
#        [[576, 195]],
#
#        [[575, 196]],
#
#        [[575, 197]],
#
#        [[572, 200]],
#
#        [[572, 201]],
#
#        [[569, 204]],
#
#        [[569, 205]],
#
#        [[567, 207]],
#
#        [[567, 209]],
#
#        [[566, 210]],
#
#        [[566, 211]],
#
#        [[564, 213]],
#
#        [[564, 215]],
#
#        [[563, 216]],
#
#        [[563, 217]],
#
#        [[562, 218]],
#
#        [[562, 221]],
#
#        [[561, 222]],
#
#        [[561, 225]],
#
#        [[560, 226]],
#
#        [[560, 229]],
#
#        [[559, 230]],
#
#        [[559, 250]],
#
#        [[560, 251]],
#
#        [[560, 254]],
#
#        [[561, 255]],
#
#        [[561, 258]],
#
#        [[562, 259]],
#
#        [[562, 261]],
#
#        [[563, 262]],
#
#        [[563, 264]],
#
#        [[564, 265]],
#
#        [[564, 266]],
#
#        [[565, 267]],
#
#        [[565, 269]],
#
#        [[566, 270]],
#
#        [[566, 271]],
#
#        [[567, 272]],
#
#        [[567, 273]],
#
#        [[569, 275]],
#
#        [[569, 276]],
#
#        [[572, 279]],
#
#        [[572, 280]],
#
#        [[574, 282]],
#
#        [[574, 283]],
#
#        [[579, 288]],
#
#        [[580, 288]],
#
#        [[582, 290]],
#
#        [[583, 290]],
#
#        [[587, 294]],
#
#        [[588, 294]],
#
#        [[590, 296]],
#
#        [[591, 296]],
#
#        [[592, 297]],
#
#        [[594, 297]],
#
#        [[595, 298]],
#
#        [[596, 298]],
#
#        [[598, 300]],
#
#        [[599, 300]],
#
#        [[600, 301]],
#
#        [[601, 301]],
#
#        [[602, 302]],
#
#        [[604, 302]],
#
#        [[605, 303]],
#
#        [[610, 303]],
#
#        [[611, 304]],
#
#        [[614, 304]],
#
#        [[615, 305]],
#
#        [[627, 305]],
#
#        [[628, 304]],
#
#        [[632, 304]],
#
#        [[633, 303]],
#
#        [[637, 303]],
#
#        [[638, 302]],
#
#        [[641, 302]],
#
#        [[642, 301]],
#
#        [[643, 301]],
#
#        [[644, 300]],
#
#        [[646, 300]],
#
#        [[647, 299]],
#
#        [[648, 299]],
#
#        [[650, 297]],
#
#        [[652, 297]],
#
#        [[653, 296]],
#
#        [[655, 296]],
#
#        [[661, 290]],
#
#        [[663, 290]],
#
#        [[674, 279]],
#
#        [[674, 278]],
#
#        [[678, 274]],
#
#        [[678, 273]],
#
#        [[679, 272]],
#
#        [[679, 271]],
#
#        [[680, 270]],
#
#        [[680, 269]],
#
#        [[681, 268]],
#
#        [[681, 267]],
#
#        [[682, 266]],
#
#        [[682, 265]],
#
#        [[683, 264]],
#
#        [[683, 262]],
#
#        [[684, 261]],
#
#        [[684, 259]],
#
#        [[685, 258]],
#
#        [[685, 256]],
#
#        [[686, 255]],
#
#        [[686, 251]],
#
#        [[687, 250]],
#
#        [[687, 232]],
#
#        [[686, 231]],
#
#        [[686, 230]],
#
#        [[685, 229]],
#
#        [[685, 226]],
#
#        [[684, 225]],
#
#        [[684, 221]],
#
#        [[683, 220]],
#
#        [[683, 216]],
#
#        [[682, 215]],
#
#        [[682, 214]],
#
#        [[681, 213]],
#
#        [[681, 210]],
#
#        [[679, 208]],
#
#        [[679, 207]],
#
#        [[678, 206]],
#
#        [[678, 205]],
#
#        [[677, 204]],
#
#        [[677, 203]],
#
#        [[675, 201]],
#
#        [[675, 200]],
#
#        [[672, 197]],
#
#        [[672, 196]],
#
#        [[664, 188]],
#
#        [[663, 188]],
#
#        [[660, 185]],
#
#        [[659, 185]],
#
#        [[657, 183]],
#
#        [[656, 183]],
#
#        [[655, 182]],
#
#        [[654, 182]],
#
#        [[653, 181]],
#
#        [[652, 181]],
#
#        [[651, 180]],
#
#        [[650, 180]],
#
#        [[649, 179]],
#
#        [[648, 179]],
#
#        [[647, 178]],
#
#        [[645, 178]],
#
#        [[644, 177]],
#
#        [[642, 177]],
#
#        [[641, 176]],
#
#        [[637, 176]],
#
#        [[636, 175]],
#
#        [[633, 175]],
#
#        [[632, 174]]], dtype=int32)]

# %%
# draw the detected contours onto image
cv2.drawContours(contour_image, large_contours, -1, (255, 0, 0))
# Out:
# array([[[185, 190, 191],
#         [185, 190, 191],
#         [185, 190, 191],
#         ...,
#         [191, 196, 194],
#         [191, 196, 194],
#         [191, 196, 195]],
#
#        [[185, 190, 191],
#         [185, 190, 191],
#         [185, 190, 191],
#         ...,
#         [190, 195, 193],
#         [190, 195, 193],
#         [191, 196, 195]],
#
#        [[185, 190, 191],
#         [185, 190, 191],
#         [185, 190, 191],
#         ...,
#         [189, 194, 192],
#         [189, 194, 192],
#         [188, 193, 192]],
#
#        ...,
#
#        [[183, 191, 190],
#         [183, 191, 190],
#         [183, 191, 190],
#         ...,
#         [164, 173, 170],
#         [162, 171, 168],
#         [161, 170, 167]],
#
#        [[183, 191, 190],
#         [183, 191, 190],
#         [183, 191, 190],
#         ...,
#         [165, 175, 169],
#         [163, 173, 167],
#         [163, 173, 167]],
#
#        [[183, 191, 190],
#         [183, 191, 190],
#         [183, 191, 190],
#         ...,
#         [158, 168, 162],
#         [160, 170, 164],
#         [161, 171, 165]]], dtype=uint8)

# %%
# display the detected contours
contour_image = cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB)
plt.imshow(contour_image)

# %%
# count the number of coins
print('there are ' + str(len(large_contours)) + ' coins in the image')
# Out:
# there are 8 coins in the image

# %%
len(large_contours)
# Out:
# 8

# %%
str(len(large_contours))
# Out:
# '8'

# %%
print('Number of coins is ', str(len(large_contours)))
# Out:
# ('Number of coins is ', '8')
